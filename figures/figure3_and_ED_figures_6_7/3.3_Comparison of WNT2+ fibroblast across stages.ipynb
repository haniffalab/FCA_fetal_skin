# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from matplotlib.pyplot import rc_context
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=100, dpi_save=1000)
sc.logging.print_header()
# Out:
# 2023-06-11 12:39:22.746043: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/R/lib:/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/amd64/server
# 2023-06-11 12:39:22.746117: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# scanpy==1.8.1 anndata==0.7.6 umap==0.5.1 numpy==1.21.1 scipy==1.8.1 pandas==1.3.1 scikit-learn==0.24.2 statsmodels==0.13.2 python-igraph==0.9.6 pynndescent==0.5.4

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %%
root_path = '/lustre/scratch126/cellgen/team298/hg6/Fetal_skin/data/final/'
save_path = '/home/jovyan/projects/skin/fetal_skin/'
sc.settings.figdir = save_path + 'figures/other plots/'

# %% [markdown]
# # Load prenatal skin dataset data object

# %%
#load data object: prenatal skin only, post qc

fskin_object = 'fetal_skin.norm.maternal_removed.20220202.h5ad'
fskin_path = root_path + fskin_object
adata = sc.read(fskin_path)
# Out:
# WARNING: Your filename has more than two extensions: ['.norm', '.maternal_removed', '.20220202', '.h5ad'].
# Only considering the two last: ['.20220202', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.norm', '.maternal_removed', '.20220202', '.h5ad'].
# Only considering the two last: ['.20220202', '.h5ad'].

# %%
print(list(adata.obs['joint_annotation_20220202'].unique()))
# Out:
# ['LYVE1++ macrophage', 'Monocyte (activated/differentiating)', 'Eo/baso/mast cell progenitor', 'DC2', 'TREM2+ macrophage', 'Monocyte precursor', 'Monocyte', 'WNT2+ fibroblast', 'Iron-recycling macrophage', 'NK cell', 'B cell', 'LTi', 'ILC3', 'Inflammatory DC', 'MEMP - Early erythroid', 'CD4 T cell', 'Pro B cell', 'HSC', 'Pre B cell', 'MHCII+ macrophage', 'LE', 'Pre pro B cell', 'Innate T type1', 'CD8 T cell', 'Myocytes', 'pDC', 'Mast cell (most mature)', 'DC1', 'Mast cell (medium)', 'Capillaries', 'Neutrophil2', 'Capillary arterioles', 'LC', 'Megakaryocyte', 'MEMP - Megak', 'Mast cell (earliest)', 'Erythroid (fetal)', 'Myoblasts', 'Myofibroblasts', 'Pre-dermal condensate', 'HOXC5+ early fibroblast', 'PEAR1+ fibroblast', 'Pericytes', 'FRZB+ early fibroblast', 'Early erythroid (embryonic)', 'Early myocytes', 'Neuron progenitors', 'Myelinating Schwann cells', 'Schwann/Schwann precursors', 'LMCD1+ mural cell', 'PLN+ mural cell', 'ILC2', 'Lymphoid progenitor', 'SPP1+ proliferating neuron progenitors', 'Adipocytes', 'Neutrophil1', 'Postcapillary venules', 'PID1+ schwann cellls', 'Early LE', 'Neuroendocrine', 'Innate T type3', 'Treg', 'ASDC', 'Early endothelial cells', 'Periderm', 'Melanocyte', 'Melanoblast', 'Dermal condensate', 'Arterioles', 'Immature basal', 'Early erythroid', 'Immature suprabasal', 'Erythroid (embryonic)', 'Venules', 'Dermal papilla', 'DPYSL2+ basal', 'Outer root sheath', 'Cuticle/cortex', 'Placode/matrix', 'POSTN+ basal', 'Suprabasal IFE', 'Companion layer', 'Inner root sheath']

# %% [markdown]
# # Comparison of WNT2+ fibroblasts early vs late determined from Milo analysis

# %% [markdown]
# ## Create milo object

# %%
#load csv (from R Milo output) - contains additional metadata column of 'Enrichment' early or late
milo_all = pd.read_csv('/home/jovyan/mount_farm/lustre/scratch126/cellgen/team298/hg6/Fetal_skin/out_files/milo_res_index_cells.csv')
milo_all
# Out:
#        Unnamed: 0                          index_cell  kth_distance  \
# 0               0  ACCCACTAGGCAGTCA-1-4834STDY7002879      1.052995
# 1               1  ACGCCAGAGCAGGTCA-1-4834STDY7002879      1.332812
# 2               2  ACGCCAGCACCACCAG-1-4834STDY7002879      1.420252
# 3               3  ATAACGCGTAGAGCTG-1-4834STDY7002879      1.358309
# 4               4  ATAGACCTCTGCGTAA-1-4834STDY7002879      1.497726
# ...           ...                                 ...           ...
# 13668       13668   TTTACTGTCTGCAGTA-1-FCAImmP7964510      1.247177
# 13669       13669   TTTCCTCTCATAAAGG-1-FCAImmP7964510      0.435837
# 13670       13670   TTTGCGCAGCCTTGAT-1-FCAImmP7964510      1.126816
# 13671       13671   TTTGTCAGTGCGAAAC-1-FCAImmP7964510      1.037427
# 13672       13672   TTTGTCATCGCAAGCC-1-FCAImmP7964510      1.320137
#
#          SpatialFDR     logFC    logCPM          F        PValue  \
# 0      8.351480e-02 -0.467129  8.509011   3.681059  5.796283e-02
# 1      5.777172e-01  0.225872  8.100582   0.426723  5.151409e-01
# 2      7.803030e-02  0.545171  8.029361   3.813226  5.375057e-02
# 3      5.767634e-01  0.455915  7.935354   2.557827  5.141347e-01
# 4      3.111774e-02 -0.499632  8.008494   5.639032  1.952530e-02
# ...             ...       ...       ...        ...           ...
# 13668  1.117032e-03  0.909980  7.625171  12.977361  4.969357e-04
# 13669  8.772952e-05  0.961300  7.341166  19.229273  2.934164e-05
# 13670  9.345316e-08  1.556564  7.540454  44.229991  5.568452e-09
# 13671  3.453115e-03  0.939307  7.671832  10.378170  1.730997e-03
# 13672  7.738544e-06  1.466573  7.823218  25.605234  1.949598e-06
#
#                 FDR    nhood_annotation  nhood_annotation_frac  logFC_signif  \
# 0      8.471681e-02  LYVE1++ macrophage               1.000000     -0.467129
# 1      5.808132e-01  Monocyte precursor               0.940000      0.225872
# 2      7.919520e-02             NK cell               0.833333      0.545171
# 3      5.798700e-01            Monocyte               0.650000      0.455915
# 4      3.178586e-02   MHCII+ macrophage               0.612245     -0.499632
# ...             ...                 ...                    ...           ...
# 13668  1.173709e-03                  LE               1.000000      0.909980
# 13669  9.470923e-05   Erythroid (fetal)               1.000000      0.961300
# 13670  9.926531e-08       DPYSL2+ basal               0.961538      1.556564
# 13671  3.588224e-03           Pericytes               0.988235      0.939307
# 13672  8.586234e-06                  LE               0.933333      1.466573
#
#                                  nhood_anno organ
# 0                        LYVE1++ macrophage    SK
# 1                        Monocyte precursor    SK
# 2                                   NK cell    SK
# 3                                  Monocyte    SK
# 4      Monocyte (activated/differentiating)    SK
# ...                                     ...   ...
# 13668                                    LE    SK
# 13669                     Erythroid (fetal)    SK
# 13670                         DPYSL2+ basal    SK
# 13671                             Pericytes    SK
# 13672                                    LE    SK
#
# [13673 rows x 14 columns]

# %%
milo_all.drop(columns=['Unnamed: 0'], inplace=True)
milo_all.rename(columns={'index_cell': 'index'}, inplace=True)
milo_all.set_index('index', inplace=True)
milo_all
# Out:
#                                     kth_distance    SpatialFDR     logFC  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879      1.052995  8.351480e-02 -0.467129
# ACGCCAGAGCAGGTCA-1-4834STDY7002879      1.332812  5.777172e-01  0.225872
# ACGCCAGCACCACCAG-1-4834STDY7002879      1.420252  7.803030e-02  0.545171
# ATAACGCGTAGAGCTG-1-4834STDY7002879      1.358309  5.767634e-01  0.455915
# ATAGACCTCTGCGTAA-1-4834STDY7002879      1.497726  3.111774e-02 -0.499632
# ...                                          ...           ...       ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510       1.247177  1.117032e-03  0.909980
# TTTCCTCTCATAAAGG-1-FCAImmP7964510       0.435837  8.772952e-05  0.961300
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510       1.126816  9.345316e-08  1.556564
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510       1.037427  3.453115e-03  0.939307
# TTTGTCATCGCAAGCC-1-FCAImmP7964510       1.320137  7.738544e-06  1.466573
#
#                                       logCPM          F        PValue  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  8.509011   3.681059  5.796283e-02
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  8.100582   0.426723  5.151409e-01
# ACGCCAGCACCACCAG-1-4834STDY7002879  8.029361   3.813226  5.375057e-02
# ATAACGCGTAGAGCTG-1-4834STDY7002879  7.935354   2.557827  5.141347e-01
# ATAGACCTCTGCGTAA-1-4834STDY7002879  8.008494   5.639032  1.952530e-02
# ...                                      ...        ...           ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510   7.625171  12.977361  4.969357e-04
# TTTCCTCTCATAAAGG-1-FCAImmP7964510   7.341166  19.229273  2.934164e-05
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510   7.540454  44.229991  5.568452e-09
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510   7.671832  10.378170  1.730997e-03
# TTTGTCATCGCAAGCC-1-FCAImmP7964510   7.823218  25.605234  1.949598e-06
#
#                                              FDR    nhood_annotation  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  8.471681e-02  LYVE1++ macrophage
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  5.808132e-01  Monocyte precursor
# ACGCCAGCACCACCAG-1-4834STDY7002879  7.919520e-02             NK cell
# ATAACGCGTAGAGCTG-1-4834STDY7002879  5.798700e-01            Monocyte
# ATAGACCTCTGCGTAA-1-4834STDY7002879  3.178586e-02   MHCII+ macrophage
# ...                                          ...                 ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510   1.173709e-03                  LE
# TTTCCTCTCATAAAGG-1-FCAImmP7964510   9.470923e-05   Erythroid (fetal)
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510   9.926531e-08       DPYSL2+ basal
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510   3.588224e-03           Pericytes
# TTTGTCATCGCAAGCC-1-FCAImmP7964510   8.586234e-06                  LE
#
#                                     nhood_annotation_frac  logFC_signif  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879               1.000000     -0.467129
# ACGCCAGAGCAGGTCA-1-4834STDY7002879               0.940000      0.225872
# ACGCCAGCACCACCAG-1-4834STDY7002879               0.833333      0.545171
# ATAACGCGTAGAGCTG-1-4834STDY7002879               0.650000      0.455915
# ATAGACCTCTGCGTAA-1-4834STDY7002879               0.612245     -0.499632
# ...                                                   ...           ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                1.000000      0.909980
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                1.000000      0.961300
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                0.961538      1.556564
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                0.988235      0.939307
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                0.933333      1.466573
#
#                                                               nhood_anno organ
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879                    LYVE1++ macrophage    SK
# ACGCCAGAGCAGGTCA-1-4834STDY7002879                    Monocyte precursor    SK
# ACGCCAGCACCACCAG-1-4834STDY7002879                               NK cell    SK
# ATAACGCGTAGAGCTG-1-4834STDY7002879                              Monocyte    SK
# ATAGACCTCTGCGTAA-1-4834STDY7002879  Monocyte (activated/differentiating)    SK
# ...                                                                  ...   ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                                     LE    SK
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                      Erythroid (fetal)    SK
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                          DPYSL2+ basal    SK
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                              Pericytes    SK
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                                     LE    SK
#
# [13673 rows x 12 columns]

# %%
len(list(milo_all.index))
# Out:
# 13673

# %%
adata_milo = adata[adata.obs.index.isin(list(milo_all.index))]
adata_milo
# Out:
# View of AnnData object with n_obs × n_vars = 13673 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts'
#     uns: 'fig1b_annotation_20220202_colors'
#     obsm: 'X_umap1', 'X_umap2'

# %%
adata_milo.obs = pd.merge(adata_milo.obs, milo_all, left_index=True, right_index=True)
adata_milo.obs
# Out:
#                                           sanger_id chemistry donor  gender  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ACGCCAGCACCACCAG-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ATAACGCGTAGAGCTG-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ATAGACCTCTGCGTAA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ...                                             ...       ...   ...     ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTCCTCTCATAAAGG-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGTCATCGCAAGCC-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
#
#                                     pcw sorting              sample  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ACGCCAGAGCAGGTCA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ACGCCAGCACCACCAG-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ATAACGCGTAGAGCTG-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ATAGACCTCTGCGTAA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ...                                 ...     ...                 ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTCCTCTCATAAAGG-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGTCATCGCAAGCC-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
#
#                                    chemistry_sorting cell_caller  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ACGCCAGAGCAGGTCA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ACGCCAGCACCACCAG-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ATAACGCGTAGAGCTG-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ATAGACCTCTGCGTAA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ...                                              ...         ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTCCTCTCATAAAGG-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGTCATCGCAAGCC-1-FCAImmP7964510     SC5P-R2_CD45en        Both
#
#                                     scrublet_score  ...     logFC    logCPM  \
# index                                               ...
# ACCCACTAGGCAGTCA-1-4834STDY7002879        0.149606  ... -0.467129  8.509011
# ACGCCAGAGCAGGTCA-1-4834STDY7002879        0.164557  ...  0.225872  8.100582
# ACGCCAGCACCACCAG-1-4834STDY7002879        0.254438  ...  0.545171  8.029361
# ATAACGCGTAGAGCTG-1-4834STDY7002879        0.225806  ...  0.455915  7.935354
# ATAGACCTCTGCGTAA-1-4834STDY7002879        0.149606  ... -0.499632  8.008494
# ...                                            ...  ...       ...       ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510         0.083573  ...  0.909980  7.625171
# TTTCCTCTCATAAAGG-1-FCAImmP7964510         0.021002  ...  0.961300  7.341166
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510         0.099042  ...  1.556564  7.540454
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510         0.125778  ...  0.939307  7.671832
# TTTGTCATCGCAAGCC-1-FCAImmP7964510         0.052632  ...  1.466573  7.823218
#
#                                             F        PValue           FDR  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879   3.681059  5.796283e-02  8.471681e-02
# ACGCCAGAGCAGGTCA-1-4834STDY7002879   0.426723  5.151409e-01  5.808132e-01
# ACGCCAGCACCACCAG-1-4834STDY7002879   3.813226  5.375057e-02  7.919520e-02
# ATAACGCGTAGAGCTG-1-4834STDY7002879   2.557827  5.141347e-01  5.798700e-01
# ATAGACCTCTGCGTAA-1-4834STDY7002879   5.639032  1.952530e-02  3.178586e-02
# ...                                       ...           ...           ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510   12.977361  4.969357e-04  1.173709e-03
# TTTCCTCTCATAAAGG-1-FCAImmP7964510   19.229273  2.934164e-05  9.470923e-05
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510   44.229991  5.568452e-09  9.926531e-08
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510   10.378170  1.730997e-03  3.588224e-03
# TTTGTCATCGCAAGCC-1-FCAImmP7964510   25.605234  1.949598e-06  8.586234e-06
#
#                                       nhood_annotation  nhood_annotation_frac  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  LYVE1++ macrophage               1.000000
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  Monocyte precursor               0.940000
# ACGCCAGCACCACCAG-1-4834STDY7002879             NK cell               0.833333
# ATAACGCGTAGAGCTG-1-4834STDY7002879            Monocyte               0.650000
# ATAGACCTCTGCGTAA-1-4834STDY7002879   MHCII+ macrophage               0.612245
# ...                                                ...                    ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                   LE               1.000000
# TTTCCTCTCATAAAGG-1-FCAImmP7964510    Erythroid (fetal)               1.000000
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510        DPYSL2+ basal               0.961538
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510            Pericytes               0.988235
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                   LE               0.933333
#
#                                     logFC_signif  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879     -0.467129
# ACGCCAGAGCAGGTCA-1-4834STDY7002879      0.225872
# ACGCCAGCACCACCAG-1-4834STDY7002879      0.545171
# ATAACGCGTAGAGCTG-1-4834STDY7002879      0.455915
# ATAGACCTCTGCGTAA-1-4834STDY7002879     -0.499632
# ...                                          ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510       0.909980
# TTTCCTCTCATAAAGG-1-FCAImmP7964510       0.961300
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510       1.556564
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510       0.939307
# TTTGTCATCGCAAGCC-1-FCAImmP7964510       1.466573
#
#                                                               nhood_anno organ
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879                    LYVE1++ macrophage    SK
# ACGCCAGAGCAGGTCA-1-4834STDY7002879                    Monocyte precursor    SK
# ACGCCAGCACCACCAG-1-4834STDY7002879                               NK cell    SK
# ATAACGCGTAGAGCTG-1-4834STDY7002879                              Monocyte    SK
# ATAGACCTCTGCGTAA-1-4834STDY7002879  Monocyte (activated/differentiating)    SK
# ...                                                                  ...   ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                                     LE    SK
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                      Erythroid (fetal)    SK
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                          DPYSL2+ basal    SK
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                              Pericytes    SK
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                                     LE    SK
#
# [13673 rows x 51 columns]

# %%
adata_milo
# Out:
# AnnData object with n_obs × n_vars = 13673 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202', 'kth_distance', 'SpatialFDR', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'nhood_annotation', 'nhood_annotation_frac', 'logFC_signif', 'nhood_anno', 'organ'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts'
#     uns: 'fig1b_annotation_20220202_colors'
#     obsm: 'X_umap1', 'X_umap2'

# %%
adata_milo.obs['Enrichment'] = 'Mixed'
adata_milo.obs.loc[(adata_milo.obs['SpatialFDR'] < 0.05) & (adata_milo.obs['logFC'] < 0), ['Enrichment']] = 'Early'
adata_milo.obs.loc[(adata_milo.obs['SpatialFDR'] < 0.05) & (adata_milo.obs['logFC'] > 0), ['Enrichment']] = 'Late'
list(adata_milo.obs['Enrichment'].unique())
# Out:
# ['Mixed', 'Early', 'Late']

# %%
#list(adata_milo.obs['Enrichment'].unique())

# %%
adata_milo.obs['Enrichment'].value_counts()
# Out:
# Late     5424
# Mixed    4822
# Early    3427
# Name: Enrichment, dtype: int64

# %%
adata_milo.obs['early_late_pcw'] = adata_milo.obs['Enrichment'].astype(str) + '_' + adata_milo.obs['pcw'].astype(str)

# %%
adata_milo.obs['early_late_celltype'] = adata_milo.obs['Enrichment'].astype(str) + '_' + adata_milo.obs['joint_annotation_20220202'].astype(str)

# %%
adata_milo.obs
# Out:
#                                           sanger_id chemistry donor  gender  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ACGCCAGCACCACCAG-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ATAACGCGTAGAGCTG-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ATAGACCTCTGCGTAA-1-4834STDY7002879  4834STDY7002879    SC3Pv2   F16    male
# ...                                             ...       ...   ...     ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTCCTCTCATAAAGG-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
# TTTGTCATCGCAAGCC-1-FCAImmP7964510    FCAImmP7964510   SC5P-R2   F71  female
#
#                                     pcw sorting              sample  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ACGCCAGAGCAGGTCA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ACGCCAGCACCACCAG-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ATAACGCGTAGAGCTG-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ATAGACCTCTGCGTAA-1-4834STDY7002879    8   CD45P     F16_male_8+1PCW
# ...                                 ...     ...                 ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTCCTCTCATAAAGG-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
# TTTGTCATCGCAAGCC-1-FCAImmP7964510    14  CD45en  F71-GEX_5_SKI_45en
#
#                                    chemistry_sorting cell_caller  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ACGCCAGAGCAGGTCA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ACGCCAGCACCACCAG-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ATAACGCGTAGAGCTG-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ATAGACCTCTGCGTAA-1-4834STDY7002879      SC3Pv2_CD45P        Both
# ...                                              ...         ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTCCTCTCATAAAGG-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510     SC5P-R2_CD45en        Both
# TTTGTCATCGCAAGCC-1-FCAImmP7964510     SC5P-R2_CD45en        Both
#
#                                     scrublet_score  ...        PValue  \
# index                                               ...
# ACCCACTAGGCAGTCA-1-4834STDY7002879        0.149606  ...  5.796283e-02
# ACGCCAGAGCAGGTCA-1-4834STDY7002879        0.164557  ...  5.151409e-01
# ACGCCAGCACCACCAG-1-4834STDY7002879        0.254438  ...  5.375057e-02
# ATAACGCGTAGAGCTG-1-4834STDY7002879        0.225806  ...  5.141347e-01
# ATAGACCTCTGCGTAA-1-4834STDY7002879        0.149606  ...  1.952530e-02
# ...                                            ...  ...           ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510         0.083573  ...  4.969357e-04
# TTTCCTCTCATAAAGG-1-FCAImmP7964510         0.021002  ...  2.934164e-05
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510         0.099042  ...  5.568452e-09
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510         0.125778  ...  1.730997e-03
# TTTGTCATCGCAAGCC-1-FCAImmP7964510         0.052632  ...  1.949598e-06
#
#                                              FDR    nhood_annotation  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879  8.471681e-02  LYVE1++ macrophage
# ACGCCAGAGCAGGTCA-1-4834STDY7002879  5.808132e-01  Monocyte precursor
# ACGCCAGCACCACCAG-1-4834STDY7002879  7.919520e-02             NK cell
# ATAACGCGTAGAGCTG-1-4834STDY7002879  5.798700e-01            Monocyte
# ATAGACCTCTGCGTAA-1-4834STDY7002879  3.178586e-02   MHCII+ macrophage
# ...                                          ...                 ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510   1.173709e-03                  LE
# TTTCCTCTCATAAAGG-1-FCAImmP7964510   9.470923e-05   Erythroid (fetal)
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510   9.926531e-08       DPYSL2+ basal
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510   3.588224e-03           Pericytes
# TTTGTCATCGCAAGCC-1-FCAImmP7964510   8.586234e-06                  LE
#
#                                     nhood_annotation_frac  logFC_signif  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879               1.000000     -0.467129
# ACGCCAGAGCAGGTCA-1-4834STDY7002879               0.940000      0.225872
# ACGCCAGCACCACCAG-1-4834STDY7002879               0.833333      0.545171
# ATAACGCGTAGAGCTG-1-4834STDY7002879               0.650000      0.455915
# ATAGACCTCTGCGTAA-1-4834STDY7002879               0.612245     -0.499632
# ...                                                   ...           ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                1.000000      0.909980
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                1.000000      0.961300
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                0.961538      1.556564
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                0.988235      0.939307
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                0.933333      1.466573
#
#                                                               nhood_anno  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879                    LYVE1++ macrophage
# ACGCCAGAGCAGGTCA-1-4834STDY7002879                    Monocyte precursor
# ACGCCAGCACCACCAG-1-4834STDY7002879                               NK cell
# ATAACGCGTAGAGCTG-1-4834STDY7002879                              Monocyte
# ATAGACCTCTGCGTAA-1-4834STDY7002879  Monocyte (activated/differentiating)
# ...                                                                  ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                                     LE
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                      Erythroid (fetal)
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                          DPYSL2+ basal
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                              Pericytes
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                                     LE
#
#                                     organ  Enrichment early_late_pcw  \
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879     SK       Mixed        Mixed_8
# ACGCCAGAGCAGGTCA-1-4834STDY7002879     SK       Mixed        Mixed_8
# ACGCCAGCACCACCAG-1-4834STDY7002879     SK       Mixed        Mixed_8
# ATAACGCGTAGAGCTG-1-4834STDY7002879     SK       Mixed        Mixed_8
# ATAGACCTCTGCGTAA-1-4834STDY7002879     SK       Early        Early_8
# ...                                   ...         ...            ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510      SK        Late        Late_14
# TTTCCTCTCATAAAGG-1-FCAImmP7964510      SK        Late        Late_14
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510      SK        Late        Late_14
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510      SK        Late        Late_14
# TTTGTCATCGCAAGCC-1-FCAImmP7964510      SK        Late        Late_14
#
#                                                            early_late_celltype
# index
# ACCCACTAGGCAGTCA-1-4834STDY7002879                    Mixed_LYVE1++ macrophage
# ACGCCAGAGCAGGTCA-1-4834STDY7002879                    Mixed_Monocyte precursor
# ACGCCAGCACCACCAG-1-4834STDY7002879                               Mixed_NK cell
# ATAACGCGTAGAGCTG-1-4834STDY7002879                              Mixed_Monocyte
# ATAGACCTCTGCGTAA-1-4834STDY7002879  Early_Monocyte (activated/differentiating)
# ...                                                                        ...
# TTTACTGTCTGCAGTA-1-FCAImmP7964510                                      Late_LE
# TTTCCTCTCATAAAGG-1-FCAImmP7964510                       Late_Erythroid (fetal)
# TTTGCGCAGCCTTGAT-1-FCAImmP7964510                           Late_DPYSL2+ basal
# TTTGTCAGTGCGAAAC-1-FCAImmP7964510                               Late_Pericytes
# TTTGTCATCGCAAGCC-1-FCAImmP7964510                                      Late_LE
#
# [13673 rows x 54 columns]

# %%
#adata_milo.write_h5ad(root_path +'milo_enrichment.h5ad')

# %% [markdown]
# ## Subset to early and late WNT2+ fibroblasts

# %%
# load adata_milo created above

# %%
adata_milo
# Out:
# AnnData object with n_obs × n_vars = 13673 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202', 'kth_distance', 'SpatialFDR', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'nhood_annotation', 'nhood_annotation_frac', 'logFC_signif', 'nhood_anno', 'organ', 'Enrichment', 'early_late_pcw', 'early_late_celltype'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts'
#     uns: 'fig1b_annotation_20220202_colors'
#     obsm: 'X_umap1', 'X_umap2'

# %%
print(list(adata_milo.obs['joint_annotation_20220202'].unique()))
# Out:
# ['LYVE1++ macrophage', 'Monocyte precursor', 'NK cell', 'Monocyte', 'Monocyte (activated/differentiating)', 'Iron-recycling macrophage', 'Megakaryocyte', 'HSC', 'WNT2+ fibroblast', 'Pre-dermal condensate', 'Myofibroblasts', 'Pericytes', 'Myoblasts', 'DC1', 'Erythroid (fetal)', 'MHCII+ macrophage', 'ILC3', 'PEAR1+ fibroblast', 'Schwann/Schwann precursors', 'Postcapillary venules', 'DC2', 'Innate T type1', 'TREM2+ macrophage', 'SPP1+ proliferating neuron progenitors', 'LTi', 'Neutrophil2', 'LC', 'Pre pro B cell', 'CD8 T cell', 'ILC2', 'Mast cell (medium)', 'LMCD1+ mural cell', 'Melanoblast', 'Neuron progenitors', 'HOXC5+ early fibroblast', 'Neuroendocrine', 'Myelinating Schwann cells', 'Periderm', 'Mast cell (earliest)', 'Capillaries', 'Lymphoid progenitor', 'MEMP - Early erythroid', 'Immature basal', 'Innate T type3', 'Pro B cell', 'Early myocytes', 'PID1+ schwann cellls', 'MEMP - Megak', 'B cell', 'Pre B cell', 'pDC', 'Treg', 'CD4 T cell', 'Mast cell (most mature)', 'Eo/baso/mast cell progenitor', 'PLN+ mural cell', 'Dermal condensate', 'Adipocytes', 'Dermal papilla', 'DPYSL2+ basal', 'Neutrophil1', 'LE', 'Inflammatory DC', 'ASDC', 'Early LE', 'Early erythroid', 'Melanocyte', 'Capillary arterioles', 'Inner root sheath', 'Arterioles', 'Placode/matrix', 'Companion layer', 'POSTN+ basal', 'Outer root sheath', 'FRZB+ early fibroblast', 'Early erythroid (embryonic)', 'Early endothelial cells', 'Erythroid (embryonic)', 'Myocytes', 'Immature suprabasal', 'Suprabasal IFE', 'Venules']

# %%
print(list(adata_milo.obs['Enrichment'].unique()))
# Out:
# ['Mixed', 'Early', 'Late']

# %%
cells_keepfib = ['WNT2+ fibroblast']
adata_milo_WNT2fib = adata_milo[adata_milo.obs['joint_annotation_20220202'].isin(cells_keepfib)]

# %%
enrichment_keep = ['Late','Early']
adata_milo_WNT2fib = adata_milo_WNT2fib[adata_milo_WNT2fib.obs['Enrichment'].isin(enrichment_keep)]
adata_milo_WNT2fib
# Out:
# View of AnnData object with n_obs × n_vars = 1233 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202', 'kth_distance', 'SpatialFDR', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'nhood_annotation', 'nhood_annotation_frac', 'logFC_signif', 'nhood_anno', 'organ', 'Enrichment', 'early_late_pcw', 'early_late_celltype'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts'
#     uns: 'fig1b_annotation_20220202_colors'
#     obsm: 'X_umap1', 'X_umap2'

# %%
#only keep genes present in about >10% cells (see method in Suo, Dann et al)
#sc.pp.filter_genes(adata_milo_WNT2fib, min_cells=120)
# Out:
# filtered out 22273 genes that are detected in less than 120 cells
# Trying to set attribute `.var` of view, copying.

# %%
#compute DEGs between early and late WNT2+ fibroblast
sc.pp.highly_variable_genes(adata_milo_WNT2fib)
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# Trying to set attribute `.uns` of view, copying.
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
adata_milo_WNT2fib
# Out:
# AnnData object with n_obs × n_vars = 1233 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202', 'kth_distance', 'SpatialFDR', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'nhood_annotation', 'nhood_annotation_frac', 'logFC_signif', 'nhood_anno', 'organ', 'Enrichment', 'early_late_pcw', 'early_late_celltype'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'fig1b_annotation_20220202_colors', 'hvg'
#     obsm: 'X_umap1', 'X_umap2'

# %%
sc.tl.rank_genes_groups(adata_milo_WNT2fib, groupby='Enrichment', key_added='rank_genes_groups_MiloFib', method = 'wilcoxon')
# Out:
# ranking genes
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'nhood_annotation' as categorical
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'nhood_anno' as categorical
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'organ' as categorical
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'Enrichment' as categorical
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'early_late_pcw' as categorical
# /home/jovyan/my-conda-envs/my_new_env_clone2/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'early_late_celltype' as categorical
#     finished: added to `.uns['rank_genes_groups_MiloFib']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:01)

# %%
sc.pl.rank_genes_groups(adata_milo_WNT2fib, n_genes=30, sharey=False, key='rank_genes_groups_MiloFib')

# %%
#get list of significant genes for early and late WNT2+ fibroblast to be used in GSEApy analysis
genes_WNT2fib_Early = sc.get.rank_genes_groups_df(adata_milo_WNT2fib, group='Early', key='rank_genes_groups_MiloFib', log2fc_min=1.00, 
                                    pval_cutoff=0.01)[['names', 'pvals', 'logfoldchanges', 'scores']]

genes_WNT2fib_Late = sc.get.rank_genes_groups_df(adata_milo_WNT2fib, group='Late', key='rank_genes_groups_MiloFib', log2fc_min=1.00, 
                                    pval_cutoff=0.01)[['names', 'pvals', 'logfoldchanges', 'scores']]

# %%
#save genes list as csv
genes_WNT2fib_Early.to_csv('/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_early_logfc1p001_11062023.csv')
genes_WNT2fib_Late.to_csv('/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_late_logfc1p001_11062023.csv')

# %%
glist_WNT2fib_Early = genes_WNT2fib_Early['names'].squeeze().str.strip().tolist()
print(len(glist_WNT2fib_Early))
# Out:
# 582

# %%
glist_WNT2fib_Late = genes_WNT2fib_Late['names'].squeeze().str.strip().tolist()
print(len(glist_WNT2fib_Late))
# Out:
# 341

# %% [markdown]
# ## GSEApy analysis

# %%
import gseapy as gp

# %%
from gseapy.plot import barplot, dotplot

# %%
enr_WNT2fibearly = gp.enrichr(gene_list=glist_WNT2fib_Early,
                 gene_sets='GO_Biological_Process_2021',
                 organism='Human',
                 #description='gseaWNT2fibearly',
                 outdir='/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_early',
                 no_plot=True,
                 cutoff=0.05)

# %%
enr_WNT2fibearly_Hallmark = gp.enrichr(gene_list=glist_WNT2fib_Early,
                 gene_sets='MSigDB_Hallmark_2020',
                 organism='Human',
                 #description='gseaWNT2fibearly',
                 outdir='/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_early',
                 no_plot=True,
                 cutoff=0.05)

# %%
enr_WNT2fiblate = gp.enrichr(gene_list=glist_WNT2fib_Late,
                 gene_sets='GO_Biological_Process_2021',
                 organism='Human',
                 #description='gseaWNT2fiblate',
                 outdir='/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_late',
                 no_plot=True,
                 cutoff=0.05)

# %%
enr_WNT2fiblate_Hallmark = gp.enrichr(gene_list=glist_WNT2fib_Late,
                 gene_sets='MSigDB_Hallmark_2020',
                 organism='Human',
                 #description='gseaWNT2fiblate',
                 outdir='/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_late',
                 no_plot=True,
                 cutoff=0.05)

# %%
enr_WNT2fibearly.results.head(10)
# Out:
#                      Gene_set  \
# 0  GO_Biological_Process_2021
# 1  GO_Biological_Process_2021
# 2  GO_Biological_Process_2021
# 3  GO_Biological_Process_2021
# 4  GO_Biological_Process_2021
# 5  GO_Biological_Process_2021
# 6  GO_Biological_Process_2021
# 7  GO_Biological_Process_2021
# 8  GO_Biological_Process_2021
# 9  GO_Biological_Process_2021
#
#                                                 Term  Overlap       P-value  \
# 0               cytoplasmic translation (GO:0002181)    18/93  1.654067e-10
# 1  cotranslational protein targeting to membrane ...    18/94  1.991275e-10
# 2  positive regulation of transcription, DNA-temp...  74/1183  3.741359e-10
# 3    cellular protein metabolic process (GO:0044267)   38/417  5.569035e-10
# 4  nuclear-transcribed mRNA catabolic process, no...   19/113  6.448220e-10
# 5  SRP-dependent cotranslational protein targetin...    17/90  7.950635e-10
# 6               protein targeting to ER (GO:0045047)   18/103  9.517853e-10
# 7  nuclear-transcribed mRNA catabolic process (GO...   23/171  1.025458e-09
# 8  regulation of cell population proliferation (G...   54/764  1.731646e-09
# 9  negative regulation of transcription, DNA-temp...   62/948  2.125930e-09
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      3.258722e-07            0                     0    8.231064
# 1      3.258722e-07            0                     0    8.122340
# 2      4.081823e-07            0                     0    2.404923
# 3      4.195405e-07            0                     0    3.509051
# 4      4.195405e-07            0                     0    6.937682
# 5      4.195405e-07            0                     0    7.973451
# 6      4.195405e-07            0                     0    7.258949
# 7      4.195405e-07            0                     0    5.357177
# 8      6.297421e-07            0                     0    2.694814
# 9      6.958168e-07            0                     0    2.493888
#
#    Combined Score                                              Genes
# 0      185.385072  EIF4A1;RPL21;RPL31;RPL23;RPL36A;RPL13A;RPL7;RP...
# 1      181.429333  SRP19;ARL6IP1;RPL21;RPL31;RPL23;RPL36A;RPL13A;...
# 2       52.202215  CSRNP1;PRDM2;ELK3;IRF2BPL;PPP3CA;ING2;MYC;HYAL...
# 3       74.773056  RPL31;TNC;RPL36A;PLOD2;NEDD8;PLAT;PRSS23;LTBP1...
# 4      146.815548  RPL21;RPL31;RPL23;RPL36A;RPL13A;RPL7;HELZ2;PPP...
# 5      167.064530  SRP19;RPL21;RPL31;RPL23;RPL36A;RPL13A;RPL7;RPS...
# 6      150.787830  SRP19;RPL21;RPL31;RPL23;RPL36A;RPL13A;RPL7;RPS...
# 7      110.883536  DDX5;RPL21;RPL31;RPL23;RPL36A;SAMD4A;RPL13A;SA...
# 8       54.365705  BTG2;CDKN1A;TES;CXCL8;TFRC;CELF1;PTEN;IRS2;CXC...
# 9       49.800587  NDUFA13;FHL2;UBE2D1;PRDM2;ELK3;IRF2BPL;ZFP36;C...

# %%
enr_WNT2fibearly_Hallmark.results.head(10)
# Out:
#                Gene_set                               Term Overlap  \
# 0  MSigDB_Hallmark_2020      TNF-alpha Signaling via NF-kB  57/200
# 1  MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition  27/200
# 2  MSigDB_Hallmark_2020                          Apoptosis  22/161
# 3  MSigDB_Hallmark_2020                     UV Response Up  18/158
# 4  MSigDB_Hallmark_2020                            Hypoxia  20/200
# 5  MSigDB_Hallmark_2020                   mTORC1 Signaling  20/200
# 6  MSigDB_Hallmark_2020                        p53 Pathway  18/200
# 7  MSigDB_Hallmark_2020            Cholesterol Homeostasis   10/74
# 8  MSigDB_Hallmark_2020                 TGF-beta Signaling    8/54
# 9  MSigDB_Hallmark_2020           IL-6/JAK/STAT3 Signaling   10/87
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  2.060115e-40      9.888552e-39            0                     0
# 1  3.288177e-11      7.891625e-10            0                     0
# 2  1.750265e-09      2.800423e-08            0                     0
# 3  8.455740e-07      1.014689e-05            0                     0
# 4  1.692641e-06      1.354113e-05            0                     0
# 5  1.692641e-06      1.354113e-05            0                     0
# 6  2.366247e-05      1.622569e-04            0                     0
# 7  5.426023e-05      3.255614e-04            0                     0
# 8  1.567082e-04      8.357773e-04            0                     0
# 9  2.156106e-04      8.964435e-04            0                     0
#
#    Odds Ratio  Combined Score  \
# 0   14.634366     1337.297725
# 1    5.411811      130.630842
# 2    5.448844      109.867755
# 3    4.394681       61.451922
# 4    3.803480       50.545279
# 5    3.803480       50.545279
# 6    3.373159       35.929606
# 7    5.286823       51.925685
# 8    5.869414       51.422666
# 9    4.391291       37.071435
#
#                                                Genes
# 0  BTG2;CDKN1A;TNFAIP8;TNC;TNFAIP3;IRS2;CXCL1;SLC...
# 1  TAGLN;CXCL8;COL11A1;TNC;TNFAIP3;PLOD2;CXCL1;SA...
# 2  JUN;TGFB2;CDKN1A;BTG2;EGR3;GADD45B;TNFRSF12A;G...
# 3  BTG2;TFRC;AMD1;HSPA2;MRPL23;CXCL2;ICAM1;NFKBIA...
# 4  ERRFI1;JUN;CDKN1A;TES;TPBG;HEXA;NEDD4L;TNFAIP3...
# 5  IDI1;XBP1;CDKN1A;BTG2;TES;SDF2L1;TFRC;IFRD1;EL...
# 6  PLK3;JUN;CDKN1A;BTG2;GADD45A;PLK2;ZBTB16;SAT1;...
# 7  ERRFI1;IDI1;EBP;ALCAM;TNFRSF12A;NFIL3;ECH1;CTN...
# 8           KLF10;HDAC1;ID2;ID1;CTNNB1;ID3;JUNB;SKIL
# 9  SOCS3;JUN;IL6;TNFRSF12A;IL1B;IRF1;STAT3;PIM1;C...

# %%
enr_WNT2fiblate.results.head(10)
# Out:
#                      Gene_set  \
# 0  GO_Biological_Process_2021
# 1  GO_Biological_Process_2021
# 2  GO_Biological_Process_2021
# 3  GO_Biological_Process_2021
# 4  GO_Biological_Process_2021
# 5  GO_Biological_Process_2021
# 6  GO_Biological_Process_2021
# 7  GO_Biological_Process_2021
# 8  GO_Biological_Process_2021
# 9  GO_Biological_Process_2021
#
#                                                 Term Overlap       P-value  \
# 0     extracellular matrix organization (GO:0030198)  34/300  2.052952e-18
# 1  extracellular structure organization (GO:0043062)  27/216  6.375359e-16
# 2  external encapsulating structure organization ...  27/217  7.170423e-16
# 3          collagen fibril organization (GO:0030199)   14/89  3.239496e-10
# 4                     eye morphogenesis (GO:0048592)    6/20  7.447413e-07
# 5  regulation of canonical Wnt signaling pathway ...  17/253  1.775329e-06
# 6     supramolecular fiber organization (GO:0097435)  20/351  2.841974e-06
# 7  cellular response to transforming growth facto...  11/114  4.056965e-06
# 8  positive regulation of Wnt signaling pathway (...  12/153  1.279185e-05
# 9  positive regulation of canonical Wnt signaling...  11/130  1.438603e-05
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      4.446694e-15            0                     0    8.074282
# 1      5.177045e-13            0                     0    8.858053
# 2      5.177045e-13            0                     0    8.810979
# 3      1.754187e-07            0                     0   11.179450
# 4      3.226219e-04            0                     0   25.132196
# 5      6.408937e-04            0                     0    4.318254
# 6      8.793881e-04            0                     0    3.638178
# 7      1.098423e-03            0                     0    6.328803
# 8      3.078572e-03            0                     0    5.048956
# 9      3.116015e-03            0                     0    5.473389
#
#    Combined Score                                              Genes
# 0      328.843317  COL18A1;SPARC;COL16A1;LAMA2;COL14A1;LAMA4;COL1...
# 1      309.933710  COL18A1;SPARC;COL16A1;LAMA2;COL14A1;LAMA4;NDNF...
# 2      307.251141  COL18A1;SPARC;COL16A1;LAMA2;COL14A1;LAMA4;NDNF...
# 3      244.275815  COL18A1;CRTAP;COL16A1;COL14A1;COL12A1;DPT;COL1...
# 4      354.621041           MFAP5;ALDH1A3;EFEMP1;COL5A1;COL5A2;MFAP2
# 5       57.180273  TCF7L2;FZD4;IGFBP4;PRICKLE1;DKK2;DKK3;COL1A1;P...
# 6       46.463207  COL18A1;CRTAP;GSN;COL16A1;TNXB;COL14A1;COL12A1...
# 7       78.572561  ACVRL1;TGFBR3;GDF10;CLEC3B;COL3A1;COL1A2;HPGD;...
# 8       56.885080  COL1A1;PSMA6;GPRC5B;ZEB2;SFRP2;PSME1;GPC3;TMEM...
# 9       61.024201  COL1A1;PSMA6;GPRC5B;ZEB2;SFRP2;PSME1;GPC3;TMEM...

# %%
enr_WNT2fiblate_Hallmark.results.head(10)
# Out:
#                Gene_set                               Term Overlap  \
# 0  MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition  32/200
# 1  MSigDB_Hallmark_2020                         Myogenesis  19/200
# 2  MSigDB_Hallmark_2020                     UV Response Dn  15/144
# 3  MSigDB_Hallmark_2020                        Coagulation  14/138
# 4  MSigDB_Hallmark_2020                    Apical Junction  13/200
# 5  MSigDB_Hallmark_2020                       Angiogenesis    5/36
# 6  MSigDB_Hallmark_2020              Xenobiotic Metabolism  11/200
# 7  MSigDB_Hallmark_2020                          Apoptosis   9/161
# 8  MSigDB_Hallmark_2020                            Hypoxia  10/200
# 9  MSigDB_Hallmark_2020                         Complement  10/200
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  5.512235e-22      2.425384e-20            0                     0
# 1  1.668861e-09      3.671495e-08            0                     0
# 2  2.577246e-08      3.779961e-07            0                     0
# 3  1.054467e-07      1.159913e-06            0                     0
# 4  4.145917e-05      3.648407e-04            0                     0
# 5  3.416466e-04      2.505409e-03            0                     0
# 6  6.692277e-04      4.206574e-03            0                     0
# 7  1.813373e-03      9.973553e-03            0                     0
# 8  2.356661e-03      1.036931e-02            0                     0
# 9  2.356661e-03      1.036931e-02            0                     0
#
#    Odds Ratio  Combined Score  \
# 0   12.014794      588.123000
# 1    6.349851      128.337622
# 2    6.966044      121.724364
# 3    6.744846      108.356354
# 4    4.127038       41.645120
# 5    9.422043       75.204237
# 6    3.433862       25.099427
# 7    3.478975       21.961262
# 8    3.095723       18.730700
# 9    3.095723       18.730700
#
#                                                Genes
# 0  SPARC;COL16A1;SERPINE2;LAMA2;COL12A1;FBLN1;LAM...
# 1  CFD;PRNP;SPARC;GSN;LAMA2;IGFBP3;FST;FHL1;COX7A...
# 2  PHF3;PIAS3;CDKN1B;CITED2;LAMC1;TFPI;TGFBR2;COL...
# 3  CFD;SPARC;ANXA1;GSN;CFH;C1S;F10;PROS1;MMP2;FN1...
# 4  COL16A1;VCAM1;MMP2;SGCE;ADAMTS5;VCAN;AKT2;EPB4...
# 5                    POSTN;VCAN;COL3A1;COL5A2;S100A4
# 6  TPST1;F10;SHMT2;IGFBP4;TMEM176B;PROS1;EPHX1;PD...
# 7  IFITM3;TGFBR3;GSTM1;CDKN1B;ANXA1;GSN;DIABLO;MM...
# 8  SELENBP1;SRPX;CDKN1B;COL5A1;CITED2;P4HA2;IGFBP...
# 9  MMP14;CFH;F10;C1S;FN1;SERPING1;ADAM9;CD46;CD55...

# %%
enr_WNT2fibearly.results.to_csv('/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_early_GOPB21_11062023.csv')
enr_WNT2fiblate.results.to_csv('/home/jovyan/projects/skin/fetal_skin/GSEA_milo/11062023/WNT2fib_late_GOPB21_11062023.csv')

# %%
gp.dotplot(enr_WNT2fibearly.res2d,title='WNT2fib_early_GOBP_2021', top_term=10, figsize=(6,6))
gp.dotplot(enr_WNT2fiblate.res2d,title='WNT2fib_late_GOBP_2021',  top_term=10, figsize=(6,6))
#gp.dotplot(enr_WNT2fibearly.res2d,title='WNT2fib_early_GOBP_2021', top_term=10, figsize=(6,6), ofname='WNT2_early_GOBP_11062023.pdf')
##gp.dotplot(enr_WNT2fibearly_Hallmark.res2d,title='WNT2fib_early_MSigDB_Hallmark_2020',  top_term=10, cmap='viridis')
#gp.dotplot(enr_WNT2fiblate.res2d,title='WNT2fib_late_GOBP_2021',  top_term=10, figsize=(6,6), ofname='WNT2_late_11062023.pdf')
##gp.dotplot(enr_WNT2fiblate_Hallmark.res2d,title='WNT2fib_late_MSigDB_Hallmark_2020',  top_term=10, cmap='viridis')
# Out:
# <AxesSubplot:title={'center':'WNT2fib_late_GOBP_2021'}, xlabel='-log$_{10}$(Adjusted P-value)'>

# %% [markdown]
# # Plot DEGs from early-late WNT2+ comparison by PCW

# %% [markdown]
# ## Create object WNT2+ fibroblast only

# %%
#slice prenatal skin object to WNT2+ fibroblast only

WNT2_fib = ['WNT2+ fibroblast']
adata_WNT2 = adata[adata.obs['joint_annotation_20220202'].isin(WNT2_fib)]
adata_WNT2
# Out:
# View of AnnData object with n_obs × n_vars = 29109 × 28885
#     obs: 'sanger_id', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'cell_caller', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'bh_doublet_pval', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'percent_hb', 'independent_annotation_refined', 'independent_annotation_broad1', 'independent_annotation_broad2', 'independent_annotation_broad3', 'independent_annotation_broad4', 'independent_annotation_broad5', 'joint_annotation', 'is_maternal', 'fig1b_annotation', 'independent_annotation_refined_20220201a', 'independent_annotation_refined_20220201b', 'independent_annotation_broad1_20220201', 'independent_annotation_broad2_20220201', 'independent_annotation_broad3_20220201', 'joint_annotation_20220201a', 'joint_annotation_20220201b', 'fig1b_annotation_20220201', 'fig1b_annotation_20220202', 'joint_annotation_20220202', 'fig1b_annotation_v2', 'independent_annotation_refined_20220202'
#     var: 'gene_ids', 'mito', 'ribo', 'hb', 'n_cells', 'cc', 'n_counts'
#     uns: 'fig1b_annotation_20220202_colors'
#     obsm: 'X_umap1', 'X_umap2'

# %%
print(list(adata_WNT2.obs['pcw'].unique()))
# Out:
# [8, 9, 10, 7, 13, 16, 12, 15, 11, 14]

# %%
new_bins = {
'7' : '7-8',
'8' : '7-8',
'9' : '9-11',
'10' : '9-11',
'11' : '9-11',
'12' : '12-13',
'13' : '12-13',
'14' : '14-16',
'15' : '14-16',
'16' : '14-16'
}
new_bins
# Out:
# {'7': '7-8',
#  '8': '7-8',
#  '9': '9-11',
#  '10': '9-11',
#  '11': '9-11',
#  '12': '12-13',
#  '13': '12-13',
#  '14': '14-16',
#  '15': '14-16',
#  '16': '14-16'}

# %%
adata_WNT2.obs['pcw_binned'] = adata_WNT2.obs['pcw'].astype(str).map(new_bins)
adata_WNT2.obs['pcw_binned'] = adata_WNT2.obs['pcw_binned'].astype('category')
adata_WNT2.obs['pcw_binned'].value_counts()
# Out:
# Trying to set attribute `.obs` of view, copying.
# 14-16    13369
# 9-11      6844
# 7-8       6067
# 12-13     2829
# Name: pcw_binned, dtype: int64

# %%
adata_WNT2.obs['pcw_binned'] = adata_WNT2.obs['pcw_binned'].cat.reorder_categories([
'7-8',
'9-11',
'12-13',
'14-16'
])

# %%
print(list(adata_WNT2.obs['joint_annotation_20220202'].unique()))
# Out:
# ['WNT2+ fibroblast']

# %% [markdown]
# ## Plot matrix plot

# %%
#Based on DEGs and GSEApy analyses above - list of genes and corresponding functions selected

# %%
#Create dictionary
markers_WNT2_earlylate = {
 'Regulation of transciption' : ['EGR1', 'IGF1', 'IRF1', 'RDX', 'RPL23', 'TWIST1'],
 'Regulation of cell proliferation' : ['MDK', 'SFRP1', 'SFRP4', 'SOX11'],
 'Extracellular matrix organisation and collagen deposition' : ['ADAMTS5', 'ADAMTSL4', 'COL1A1', 'COL1A2', 'COL3A1', 'COL5A1', 'COL6A3', 'COL12A1', 'COL14A1', 'COL16A1',
                                                                'MFAP2', 'MFAP5', 'MMP14', 'POSTN', 'SPARC']}

# %%
sc.pl.matrixplot(adata_WNT2, var_names=markers_WNT2_earlylate, groupby='pcw_binned', standard_scale='var', 
                 cmap='coolwarm')

#sc.pl.matrixplot(adata_WNT2, var_names=markers_WNT2_earlylate, groupby='pcw_binned', standard_scale='var', 
#                 cmap='coolwarm', return_fig=True).savefig('/home/jovyan/projects/skin/fetal_skin/figures/marker_panels/figures_28042023/WNT2_comparison_groups_11062023.pdf')

# %%
#plot same genes without functional annotations

sc.pl.matrixplot(adata_WNT2, var_names=['EGR1', 'IGF1', 'IRF1', 'RDX', 'RPL23', 'TWIST1', 'MDK', 'SFRP1', 'SFRP4', 'SOX11', 
                           'ADAMTS5', 'ADAMTSL4', 'COL1A1', 'COL1A2', 'COL3A1', 'COL5A1', 'COL6A3', 'COL12A1', 'COL14A1', 'COL16A1',
                                        'MFAP2', 'MFAP5', 'MMP14', 'POSTN', 'SPARC'], groupby='pcw_binned', 
                 standard_scale='var', cmap='coolwarm')

#sc.pl.matrixplot(adata_WNT2, var_names=['EGR1', 'IGF1', 'IRF1', 'RDX', 'RPL23', 'TWIST1', 'MDK', 'SFRP1', 'SFRP4', 'SOX11', 
#                           'ADAMTS5', 'ADAMTSL4', 'COL1A1', 'COL1A2', 'COL3A1', 'COL5A1', 'COL6A3', 'COL12A1', 'COL14A1', 'COL16A1',
#                                        'MFAP2', 'MFAP5', 'MMP14', 'POSTN', 'SPARC'], groupby='pcw_binned', 
#                 standard_scale='var', cmap='coolwarm', return_fig=True).savefig('/home/jovyan/projects/skin/fetal_skin/figures/marker_panels/figures_28042023/WNT2_comparison_nogroups_11062023.pdf')
