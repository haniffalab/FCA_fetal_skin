# %%
# env sctk2

# %load_ext autoreload
# %autoreload 2

import os, re, gc 
#joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.pyplot import rc_context
import seaborn as sn
import anndata
import scanpy as sc
#import scvelo as scv
import sctk as sk
#import cellrank as cr

rcParams["pdf.fonttype"] = 42
rcParams["ps.fonttype"] = 42
expr_cmap = sk.expression_colormap()
np.set_printoptions(linewidth=150)

import numpy_groupies as npg
#from plotnine import ggplot, aes
#import plotnine as pln
from matplotlib.colors import ListedColormap

import matplotlib
import matplotlib.cm as cm

from statsmodels.stats.multitest import fdrcorrection

from scipy.stats import pearsonr, spearmanr

import scipy.sparse as sp

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
# Out:
# scanpy==1.9.3 anndata==0.8.0 umap==0.5.1 numpy==1.23.4 scipy==1.9.3 pandas==1.5.1 scikit-learn==1.1.3 statsmodels==0.13.5 python-igraph==0.10.4 pynndescent==0.5.8

# %%
#root_path = '/lustre/scratch126/cellgen/team298/hg6/Fetal_skin/data/final/'
root_path = '/home/jovyan/projects/skin/fetal_skin/'
save_path = '/home/jovyan/projects/skin/fetal_skin/'
sc.settings.figdir = save_path + 'figures/other plots/'

# %% [markdown]
# # Cell-cell interactions in skin organoid: related to Hair follicle formation

# %%
#Load organoid CPDB summary files
org_path = root_path + 'cpdb/cpdb_organoid.tsv'
cpdb_org = pd.read_csv(org_path, delimiter="\t")
cpdb_org
# Out:
#                gene_pair                            celltype_pair   mean  \
# 0             FGF2|FGFR2                         Adipocytes|Basal  0.282
# 1             CD44|FGFR2                         Adipocytes|Basal  0.627
# 2             FGF7|FGFR2                         Adipocytes|Basal  0.377
# 3            TIMP1|FGFR2                         Adipocytes|Basal  1.043
# 4            FGFR1|FGFR2                         Adipocytes|Basal  0.676
# ...                  ...                                      ...    ...
# 20524  TNFSF12|TNFRSF12A  Tip cell (arterial)|Tip cell (arterial)  0.242
# 20525          CKLF|LRP6  Tip cell (arterial)|Tip cell (arterial)  0.488
# 20526        PROS1|TYRO3  Tip cell (arterial)|Tip cell (arterial)  0.323
# 20527          KITLG|KIT  Tip cell (arterial)|Tip cell (arterial)  0.314
# 20528         KITLG|EPOR  Tip cell (arterial)|Tip cell (arterial)  0.301
#
#            p      padj
# 0      0.000  0.000000
# 1      0.000  0.000000
# 2      0.000  0.000000
# 3      0.000  0.000000
# 4      0.000  0.000000
# ...      ...       ...
# 20524  0.005  0.079687
# 20525  0.000  0.000000
# 20526  0.000  0.000000
# 20527  0.000  0.000000
# 20528  0.000  0.000000
#
# [20529 rows x 5 columns]

# %%
cpdb_org.shape
# Out:
# (20529, 5)

# %%
# list of fibroblasts in data
#fib = ['Dermal condensate', 'Dermal papillia', 'HOXC5+ early fibroblast', 'PEAR1+ fibroblast', 'Pre-dermal condensate', 'WNT2+ fibroblast']
fib = ['Dermal condensate', 'Dermal papillia', 'Early fibroblasts HOXC5', 'Fibroblasts POSTN+', 'Pre-dermal condensate']

# %%
#keratinocytes = ['Basal KC', 'Early KC (stem cell)', 'Hair follicle', 'Suprabasal']

# %%
# list of keratinocytes in data
keratinocytes_joint = ['Basal', 'Companion layer', 'Cuticle/cortex', 'Immature basal', 'Immature suprabasal', 'Inner root sheath', 'Outer root sheath',
                       'Basal POSTN+', 'Basal SHH+', 'Suprabasal IFE']

# %%
# list of HF fibroblasts in data
fib2 = ['Dermal condensate', 'Dermal papillia', 'Early fibroblasts HOXC5', 'Pre-dermal condensate']

# %%
# HF fibroblasts - early
fib4 = ['Early fibroblasts HOXC5', 'Pre-dermal condensate']

# %%
# HF fibroblasts - late
fib5 = ['Dermal condensate', 'Dermal papillia']

# %%
# obtain interactions for early HF fibroblasts
cpdb_fib6 = pd.DataFrame()
for i in fib4:
    print(i)
    temp = cpdb_org[(cpdb_org['celltype_pair'].str.startswith(i)) & (cpdb_org['celltype_pair'].str.contains('immature', case=False))]
    temp['Fibroblast'] = i
    temp['cell_pair'] = i + '_Epithelial_early'
    cpdb_fib6 = pd.concat([cpdb_fib6, temp])
cpdb_fib6
# Out:
# Early fibroblasts HOXC5
# Pre-dermal condensate
#            gene_pair                              celltype_pair   mean    p  \
# 7437      CD44|FGFR2     Early fibroblasts HOXC5|Immature basal  0.468  0.0
# 7438     FGF18|FGFR2     Early fibroblasts HOXC5|Immature basal  0.490  0.0
# 7439      FGF7|FGFR2     Early fibroblasts HOXC5|Immature basal  0.613  0.0
# 7440     TIMP1|FGFR2     Early fibroblasts HOXC5|Immature basal  0.716  0.0
# 7441     FGFR1|FGFR2     Early fibroblasts HOXC5|Immature basal  0.888  0.0
# ...              ...                                        ...    ...  ...
# 17023    FGFR2|EPHA4  Pre-dermal condensate|Immature suprabasal  0.390  0.0
# 17024    EFNA4|EPHA4  Pre-dermal condensate|Immature suprabasal  0.289  0.0
# 17025  FGFR2|NECTIN1  Pre-dermal condensate|Immature suprabasal  0.329  0.0
# 17026     RSPO4|LGR4  Pre-dermal condensate|Immature suprabasal  0.132  0.0
# 17027     RSPO1|LGR4  Pre-dermal condensate|Immature suprabasal  0.188  0.0
#
#        padj               Fibroblast                                 cell_pair
# 7437    0.0  Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7438    0.0  Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7439    0.0  Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7440    0.0  Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7441    0.0  Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# ...     ...                      ...                                       ...
# 17023   0.0    Pre-dermal condensate    Pre-dermal condensate_Epithelial_early
# 17024   0.0    Pre-dermal condensate    Pre-dermal condensate_Epithelial_early
# 17025   0.0    Pre-dermal condensate    Pre-dermal condensate_Epithelial_early
# 17026   0.0    Pre-dermal condensate    Pre-dermal condensate_Epithelial_early
# 17027   0.0    Pre-dermal condensate    Pre-dermal condensate_Epithelial_early
#
# [96 rows x 7 columns]

# %%
# remove Immature suprabasal/suprabasal IFE 
cpdb_fib6filt = cpdb_fib6[~ cpdb_fib6['celltype_pair'].str.contains('suprabasal', case=False)]
cpdb_fib6filt.shape
# Out:
# (51, 7)

# %%
# obtain interactions for late HF fibroblasts
cpdb_fib7 = pd.DataFrame()
for i in fib5:
    print(i)
    temp = cpdb_org[(cpdb_org['celltype_pair'].str.startswith(i)) & (cpdb_org['celltype_pair'].str.contains('basal|companion|cuticle|sheath', case=False))]
    temp['Fibroblast'] = i
    temp['cell_pair'] = i + '_Epithelial_late'
    cpdb_fib7 = pd.concat([cpdb_fib7, temp])
cpdb_fib7
# Out:
# Dermal condensate
# Dermal papillia
#          gene_pair                   celltype_pair   mean    p  padj  \
# 832    FAM3C|HLA-C         Dermal condensate|Basal  0.531  0.0   0.0
# 833    FAM3C|LAMP1         Dermal condensate|Basal  0.601  0.0   0.0
# 834    FAM3C|CXADR         Dermal condensate|Basal  0.868  0.0   0.0
# 835     TGFB1|EGFR         Dermal condensate|Basal  0.364  0.0   0.0
# 836       MIF|EGFR         Dermal condensate|Basal  0.812  0.0   0.0
# ...            ...                             ...    ...  ...   ...
# 19120     GRN|EGFR  Dermal papillia|Suprabasal IFE  0.397  0.0   0.0
# 19121    COPA|EGFR  Dermal papillia|Suprabasal IFE  0.407  0.0   0.0
# 19128  EFNB1|EPHB6  Dermal papillia|Suprabasal IFE  0.265  0.0   0.0
# 19129   WNT5A|FZD6  Dermal papillia|Suprabasal IFE  0.879  0.0   0.0
# 19130   RSPO3|LGR4  Dermal papillia|Suprabasal IFE  1.116  0.0   0.0
#
#               Fibroblast                          cell_pair
# 832    Dermal condensate  Dermal condensate_Epithelial_late
# 833    Dermal condensate  Dermal condensate_Epithelial_late
# 834    Dermal condensate  Dermal condensate_Epithelial_late
# 835    Dermal condensate  Dermal condensate_Epithelial_late
# 836    Dermal condensate  Dermal condensate_Epithelial_late
# ...                  ...                                ...
# 19120    Dermal papillia    Dermal papillia_Epithelial_late
# 19121    Dermal papillia    Dermal papillia_Epithelial_late
# 19128    Dermal papillia    Dermal papillia_Epithelial_late
# 19129    Dermal papillia    Dermal papillia_Epithelial_late
# 19130    Dermal papillia    Dermal papillia_Epithelial_late
#
# [527 rows x 7 columns]

# %%
# remove Immature suprabasal/suprabasal IFE and Immature basal
cpdb_fib7filt = cpdb_fib7[~ cpdb_fib7['celltype_pair'].str.contains('suprabasal|immature', case=False)]
cpdb_fib7filt.shape
# Out:
# (390, 7)

# %%
bind_fib2=[cpdb_fib6filt, cpdb_fib7filt]
cpdb_fib8 = pd.concat(bind_fib2)
cpdb_fib8
# Out:
#          gene_pair                           celltype_pair   mean    p  padj  \
# 7437    CD44|FGFR2  Early fibroblasts HOXC5|Immature basal  0.468  0.0   0.0
# 7438   FGF18|FGFR2  Early fibroblasts HOXC5|Immature basal  0.490  0.0   0.0
# 7439    FGF7|FGFR2  Early fibroblasts HOXC5|Immature basal  0.613  0.0   0.0
# 7440   TIMP1|FGFR2  Early fibroblasts HOXC5|Immature basal  0.716  0.0   0.0
# 7441   FGFR1|FGFR2  Early fibroblasts HOXC5|Immature basal  0.888  0.0   0.0
# ...            ...                                     ...    ...  ...   ...
# 15670    COPA|EGFR       Dermal papillia|Outer root sheath  0.506  0.0   0.0
# 15671   VEGFB|NRP1       Dermal papillia|Outer root sheath  0.409  0.0   0.0
# 15676  EFNB1|EPHB6       Dermal papillia|Outer root sheath  0.468  0.0   0.0
# 15677   WNT5A|FZD6       Dermal papillia|Outer root sheath  0.982  0.0   0.0
# 15678   RSPO3|LGR4       Dermal papillia|Outer root sheath  1.260  0.0   0.0
#
#                     Fibroblast                                 cell_pair
# 7437   Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7438   Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7439   Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7440   Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# 7441   Early fibroblasts HOXC5  Early fibroblasts HOXC5_Epithelial_early
# ...                        ...                                       ...
# 15670          Dermal papillia           Dermal papillia_Epithelial_late
# 15671          Dermal papillia           Dermal papillia_Epithelial_late
# 15676          Dermal papillia           Dermal papillia_Epithelial_late
# 15677          Dermal papillia           Dermal papillia_Epithelial_late
# 15678          Dermal papillia           Dermal papillia_Epithelial_late
#
# [441 rows x 7 columns]

# %%
print(cpdb_fib8['celltype_pair'].unique())
# Out:
# ['Early fibroblasts HOXC5|Immature basal' 'Pre-dermal condensate|Immature basal' 'Dermal condensate|Basal' 'Dermal condensate|Basal POSTN+'
#  'Dermal condensate|Basal SHH+' 'Dermal condensate|Companion layer' 'Dermal condensate|Cuticle/cortex' 'Dermal condensate|Inner root sheath'
#  'Dermal condensate|Outer root sheath' 'Dermal papillia|Basal' 'Dermal papillia|Basal POSTN+' 'Dermal papillia|Basal SHH+'
#  'Dermal papillia|Companion layer' 'Dermal papillia|Cuticle/cortex' 'Dermal papillia|Inner root sheath' 'Dermal papillia|Outer root sheath']

# %%
print(cpdb_fib8['cell_pair'].unique())
# Out:
# ['Early fibroblasts HOXC5_Epithelial_early' 'Pre-dermal condensate_Epithelial_early' 'Dermal condensate_Epithelial_late'
#  'Dermal papillia_Epithelial_late']

# %%
# grouby gene_pair/cell_pair and compute mean of interaction means
array_fib8 = cpdb_fib8.groupby(['gene_pair', 'cell_pair'])['mean'].mean().to_frame(name='new_mean').reset_index()
array_fib8
# Out:
#        gene_pair                                 cell_pair  new_mean
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early    0.1340
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late    0.5908
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late    0.6340
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late    0.6344
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early    0.4680
# ..           ...                                       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early    0.3320
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early    0.2600
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late    0.2834
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late    0.8614
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early    0.2480
#
# [135 rows x 3 columns]

# %%
# find min adjusted p-value for each combination of gene_pair-cell_pair
gene_pair = list(array_fib8['gene_pair'])
cell_pair = list(array_fib8['cell_pair'])
cpdb_fib8_p = cpdb_fib8.loc[(cpdb_fib8['gene_pair'].isin(gene_pair)) & (cpdb_fib8['cell_pair'].isin(cell_pair))]
cpdb_fib8_p = cpdb_fib8_p.groupby(['gene_pair', 'cell_pair'])['padj'].min().to_frame(name='min_padj').reset_index()
cpdb_fib8_p
# Out:
#        gene_pair                                 cell_pair  min_padj
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early       0.0
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late       0.0
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late       0.0
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late       0.0
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early       0.0
# ..           ...                                       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early       0.0
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early       0.0
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late       0.0
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late       0.0
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early       0.0
#
# [135 rows x 3 columns]

# %%
# add min adlisted p-value to means dataframe
gene_pair2 = list(cpdb_fib8_p['gene_pair'])
cell_pair2 = list(cpdb_fib8_p['cell_pair'])
array_fib8.loc[(array_fib8['gene_pair'].isin(gene_pair2)) & (array_fib8['cell_pair'].isin(cell_pair2)), 'min_padj'] = cpdb_fib8_p['min_padj']
array_fib8
# Out:
#        gene_pair                                 cell_pair  new_mean  min_padj
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early    0.1340       0.0
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late    0.5908       0.0
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late    0.6340       0.0
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late    0.6344       0.0
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early    0.4680       0.0
# ..           ...                                       ...       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early    0.3320       0.0
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early    0.2600       0.0
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late    0.2834       0.0
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late    0.8614       0.0
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early    0.2480       0.0
#
# [135 rows x 4 columns]

# %%
# filter to min adjusted p-value <0.05
array_fib8 = array_fib8[array_fib8['min_padj'] < 0.05]
array_fib8
# Out:
#        gene_pair                                 cell_pair  new_mean  min_padj
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early    0.1340       0.0
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late    0.5908       0.0
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late    0.6340       0.0
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late    0.6344       0.0
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early    0.4680       0.0
# ..           ...                                       ...       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early    0.3320       0.0
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early    0.2600       0.0
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late    0.2834       0.0
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late    0.8614       0.0
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early    0.2480       0.0
#
# [125 rows x 4 columns]

# %%
array_fib8['Fibroblast'] = [x.split('_')[0] for x in array_fib8['cell_pair']]
array_fib8
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early    0.1340
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late    0.5908
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late    0.6340
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late    0.6344
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early    0.4680
# ..           ...                                       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early    0.3320
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early    0.2600
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late    0.2834
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late    0.8614
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early    0.2480
#
#      min_padj               Fibroblast
# 0         0.0    Pre-dermal condensate
# 1         0.0          Dermal papillia
# 2         0.0        Dermal condensate
# 3         0.0          Dermal papillia
# 4         0.0  Early fibroblasts HOXC5
# ..        ...                      ...
# 130       0.0  Early fibroblasts HOXC5
# 131       0.0    Pre-dermal condensate
# 132       0.0        Dermal condensate
# 133       0.0          Dermal papillia
# 134       0.0  Early fibroblasts HOXC5
#
# [125 rows x 5 columns]

# %%
# obtain top 10 interactions per cell pair
array_fib8_top = array_fib8.groupby('cell_pair').apply(lambda grp: grp.nlargest(10, 'new_mean')).reset_index(drop=True)
array_fib8_top
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 0       MIF|EGFR         Dermal condensate_Epithelial_late  0.852429
# 1    FAM3C|CXADR         Dermal condensate_Epithelial_late  0.839857
# 2    TIMP1|FGFR2         Dermal condensate_Epithelial_late  0.799571
# 3      MDK|SORL1         Dermal condensate_Epithelial_late  0.799500
# 4    FGFR1|FGFR2         Dermal condensate_Epithelial_late  0.774000
# 5     VEGFA|NRP2         Dermal condensate_Epithelial_late  0.745500
# 6    FAM3C|LAMP1         Dermal condensate_Epithelial_late  0.704571
# 7     CD44|FGFR2         Dermal condensate_Epithelial_late  0.634000
# 8       PGF|NRP2         Dermal condensate_Epithelial_late  0.576250
# 9      COPA|EGFR         Dermal condensate_Epithelial_late  0.547143
# 10    RSPO3|LGR4           Dermal papillia_Epithelial_late  1.216143
# 11    RSPO3|LGR6           Dermal papillia_Epithelial_late  1.138667
# 12    RSPO3|LGR5           Dermal papillia_Epithelial_late  1.138000
# 13    WNT5A|FZD6           Dermal papillia_Epithelial_late  0.928000
# 14   FAM3C|CXADR           Dermal papillia_Epithelial_late  0.913571
# 15   FGFR1|FGFR2           Dermal papillia_Epithelial_late  0.907143
# 16    WNT5A|FZD3           Dermal papillia_Epithelial_late  0.885667
# 17   WNT5A|PTPRK           Dermal papillia_Epithelial_late  0.861400
# 18      MIF|EGFR           Dermal papillia_Epithelial_late  0.841429
# 19  WNT5A|ANTXR1           Dermal papillia_Epithelial_late  0.832667
# 20      MDK|LRP1  Early fibroblasts HOXC5_Epithelial_early  1.224000
# 21   FGFR1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0
sorter = ['Early fibroblasts HOXC5_Epithelial_early', 'Pre-dermal condensate_Epithelial_early', 'Dermal condensate_Epithelial_late','Dermal papillia_Epithelial_late']
sorterIndex = dict(zip(sorter, range(len(sorter))))
array_fib8_top['cell_pair_Rank'] = array_fib8_top['cell_pair'].map(sorterIndex)
array_fib8_top.sort_values(['cell_pair_Rank', 'new_mean'],ascending = [True, False], inplace = True)
array_fib8_top.drop('cell_pair_Rank', 1, inplace = True)
array_fib8_top
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 20      MDK|LRP1  Early fibroblasts HOXC5_Epithelial_early  1.224000
# 21   FGFR1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.888000
# 22   TIMP1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.716000
# 23  CXCL12|ACKR3  Early fibroblasts HOXC5_Epithelial_early  0.657000
# 24    FGF7|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.613000
# 25   FGF18|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.490000
# 26     COPA|EGFR  Early fibroblasts HOXC5_Epithelial_early  0.480000
# 27    CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.468000
# 28    RSPO3|LGR4  Early fibroblasts HOXC5_Epithelial_early  0.436000
# 29    WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early  0.332000
# 30      MDK|LRP1    Pre-dermal condensate_Epithelial_early  0.955000
# 31   TIMP1|FGFR2    Pre-dermal condensate_Epithelial_early  0.952000
# 32   FGFR1|FGFR2    Pre-dermal condensate_Epithelial_early  0.868000
# 33      MIF|EGFR    Pre-dermal condensate_Epithelial_early  0.851000
# 34    CD44|FGFR2    Pre-dermal condensate_Epithelial_early  0.767000
# 35   FAM3C|LAMP1    Pre-dermal condensate_Epithelial_early  0.615000
# 36   FAM3C|CXADR    Pre-dermal condensate_Epithelial_early  0.561000
# 37    FGF7|FGFR2    Pre-dermal condensate_Epithelial_early  0.501000
# 38     COPA|EGFR    Pre-dermal condensate_Epithelial_early  0.487000
# 39   VEGFA|EPHB2    Pre-dermal condensate_Epithelial_early  0.477000
# 0       MIF|EGFR         Dermal condensate_Epithelial_late  0.852429
# 1    FAM3C|CXADR         Dermal condensate_Epithelial_late  0.839857
# 2    TIMP1|FGFR2         Dermal condensate_Epithelial_late  0.799571
# 3      MDK|SORL1         Dermal condensate_Epithelial_late  0.799500
# 4    FGFR1|FGFR2         Dermal condensate_Epithelial_late  0.774000
# 5     VEGFA|NRP2         Dermal condensate_Epithelial_late  0.745500
# 6    FAM3C|LAMP1         Dermal condensate_Epithelial_late  0.704571
# 7     CD44|FGFR2         Dermal condensate_Epithelial_late  0.634000
# 8       PGF|NRP2         Dermal condensate_Epithelial_late  0.576250
# 9      COPA|EGFR         Dermal condensate_Epithelial_late  0.547143
# 10    RSPO3|LGR4           Dermal papillia_Epithelial_late  1.216143
# 11    RSPO3|LGR6           Dermal papillia_Epithelial_late  1.138667
# 12    RSPO3|LGR5           Dermal papillia_Epithelial_late  1.138000
# 13    WNT5A|FZD6           Dermal papillia_Epithelial_late  0.928000
# 14   FAM3C|CXADR           Dermal papillia_Epithelial_late  0.913571
# 15   FGFR1|FGFR2           Dermal papillia_Epithelial_late  0.907143
# 16    WNT5A|FZD3           Dermal papillia_Epithelial_late  0.885667
# 17   WNT5A|PTPRK           Dermal papillia_Epithelial_late  0.861400
# 18      MIF|EGFR           Dermal papillia_Epithelial_late  0.841429
# 19  WNT5A|ANTXR1           Dermal papillia_Epithelial_late  0.832667
#
#     min_padj               Fibroblast
# 20       0.0  Early fibroblasts HOXC5
# 21       0.0  Early fibroblasts HOXC5
# 22       0.0  Early fibroblasts HOXC5
# 23       0.0  Early fibroblasts HOXC5
# 24       0.0  Early fibroblasts HOXC5
# 25       0.0  Early fibroblasts HOXC5
# 26       0.0  Early fibroblasts HOXC5
# 27       0.0  Early fibroblasts HOXC5
# 28       0.0  Early fibroblasts HOXC5
# 29       0.0  Early fibroblasts HOXC5
# 30       0.0    Pre-dermal condensate
# 31       0.0    Pre-dermal condensate
# 32       0.0    Pre-dermal condensate
# 33       0.0    Pre-dermal condensate
# 34       0.0    Pre-dermal condensate
# 35       0.0    Pre-dermal condensate
# 36       0.0    Pre-dermal condensate
# 37       0.0    Pre-dermal condensate
# 38       0.0    Pre-dermal condensate
# 39       0.0    Pre-dermal condensate
# 0        0.0        Dermal condensate
# 1        0.0        Dermal condensate
# 2        0.0        Dermal condensate
# 3        0.0        Dermal condensate
# 4        0.0        Dermal condensate
# 5        0.0        Dermal condensate
# 6        0.0        Dermal condensate
# 7        0.0        Dermal condensate
# 8        0.0        Dermal condensate
# 9        0.0        Dermal condensate
# 10       0.0          Dermal papillia
# 11       0.0          Dermal papillia
# 12       0.0          Dermal papillia
# 13       0.0          Dermal papillia
# 14       0.0          Dermal papillia
# 15       0.0          Dermal papillia
# 16       0.0          Dermal papillia
# 17       0.0          Dermal papillia
# 18       0.0          Dermal papillia
# 19       0.0          Dermal papillia

# %%
array_fib8_plot = array_fib8_top.pivot_table(index='gene_pair', columns='cell_pair', values='new_mean', sort=False)

# %%
column_order = ['Early fibroblasts HOXC5_Epithelial_early', 'Pre-dermal condensate_Epithelial_early', 'Dermal condensate_Epithelial_late','Dermal papillia_Epithelial_late']
array_fib8_plot = array_fib8_plot.replace(np.nan, 0) # copy df but with nans as 0
array_fib8_plot = array_fib8_plot[column_order] # reorder columns to correct order (x axis)

# %%
# Plot - organoid top 10
plt.subplots(figsize=(3,6))
ax = sn.heatmap(array_fib8_plot, cmap='rocket_r', linewidths=0.5, linecolor='white', square = True, annot=False, xticklabels=1, yticklabels=1, cbar_kws={"shrink": 0.5, 'label':'mean'})
for i in [plt.xticks, plt.yticks]:
    i(fontsize=8) 
for i in [ax.xaxis.label.set_size, ax.yaxis.label.set_size]:
    i(8)
plt.savefig('/home/jovyan/projects/skin/fetal_skin/figures/marker_panels/CPDB_top10_organoid.pdf',dpi=300, bbox_inches = "tight")

# %%
plt.subplots(figsize=(3,6))
ax = sn.heatmap(array_fib8_plot, cmap='rocket_r', linewidths=0.5, linecolor='white', square = True, 
                 annot=False, xticklabels=['HOXC5+ early fibroblast', 'Pre-dermal condensate', 'Dermal condensate','Dermal papilla'], yticklabels=1, cbar_kws={"shrink": 0.3, 'label':'mean'})
for i in [plt.xticks, plt.yticks]:
    i(fontsize=8) 
for i in [ax.xaxis.label.set_size, ax.yaxis.label.set_size]:
    i(8)
#plt.savefig('/home/jovyan/projects/skin/fetal_skin/figures/marker_panels/CPDB_10_23102022_v2.pdf',dpi=300, bbox_inches = "tight")

# %% [markdown]
# # Subset to interactions in common with FS (top 10)

# %%
array_fib8
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 0      BDNF|F11R    Pre-dermal condensate_Epithelial_early    0.1340
# 1     BMP7|PTPRK           Dermal papillia_Epithelial_late    0.5908
# 2     CD44|FGFR2         Dermal condensate_Epithelial_late    0.6340
# 3     CD44|FGFR2           Dermal papillia_Epithelial_late    0.6344
# 4     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early    0.4680
# ..           ...                                       ...       ...
# 130   WNT5A|FZD6  Early fibroblasts HOXC5_Epithelial_early    0.3320
# 131   WNT5A|FZD6    Pre-dermal condensate_Epithelial_early    0.2600
# 132  WNT5A|PTPRK         Dermal condensate_Epithelial_late    0.2834
# 133  WNT5A|PTPRK           Dermal papillia_Epithelial_late    0.8614
# 134  WNT5A|PTPRK  Early fibroblasts HOXC5_Epithelial_early    0.2480
#
#      min_padj               Fibroblast
# 0         0.0    Pre-dermal condensate
# 1         0.0          Dermal papillia
# 2         0.0        Dermal condensate
# 3         0.0          Dermal papillia
# 4         0.0  Early fibroblasts HOXC5
# ..        ...                      ...
# 130       0.0  Early fibroblasts HOXC5
# 131       0.0    Pre-dermal condensate
# 132       0.0        Dermal condensate
# 133       0.0          Dermal papillia
# 134       0.0  Early fibroblasts HOXC5
#
# [125 rows x 5 columns]

# %%
list(array_fib8['gene_pair'].unique())
# Out:
# ['BDNF|F11R',
#  'BMP7|PTPRK',
#  'CD44|FGFR2',
#  'COPA|EGFR',
#  'COPA|SORT1',
#  'CXCL12|ACKR3',
#  'CXCL12|DPP4',
#  'EFNA4|EPHA1',
#  'EFNA4|EPHA2',
#  'EFNA4|EPHA4',
#  'EFNB1|EPHB6',
#  'FAM3C|CLEC2D',
#  'FAM3C|CXADR',
#  'FAM3C|HLA-C',
#  'FAM3C|LAMP1',
#  'FGF18|FGFR2',
#  'FGF18|FGFR3',
#  'FGF7|FGFR2',
#  'FGF7|FGFR3',
#  'FGFR1|FGFR2',
#  'FGFR2|CD83',
#  'FGFR2|EPHA4',
#  'FGFR2|FGFR3',
#  'FGFR2|NECTIN1',
#  'FGFR2|XPR1',
#  'FGFR3|EPHA4',
#  'FGFR3|NECTIN1',
#  'GRN|EGFR',
#  'GRN|SORT1',
#  'IGF1|IGF1R',
#  'MDK|LRP1',
#  'MDK|SORL1',
#  'MIF|EGFR',
#  'NECTIN3|NECTIN1',
#  'PGF|NRP2',
#  'PSAP|GPR37',
#  'RSPO1|LGR4',
#  'RSPO1|LGR5',
#  'RSPO1|LGR6',
#  'RSPO3|LGR4',
#  'RSPO3|LGR5',
#  'RSPO3|LGR6',
#  'RSPO4|LGR4',
#  'TGFB1|EGFR',
#  'TGFB2|TGFBR3',
#  'TIMP1|FGFR2',
#  'TNFSF12|TNFRSF12A',
#  'TNFSF12|TNFRSF25',
#  'VEGFA|EPHB2',
#  'VEGFA|NRP2',
#  'VEGFB|NRP1',
#  'WNT5A|ANTXR1',
#  'WNT5A|FZD1',
#  'WNT5A|FZD3',
#  'WNT5A|FZD6',
#  'WNT5A|PTPRK']

# %%
# keep only interactions present in FS plot (top 10)
# see Figure 2i - CPDB interactions in prenatal skin related to HF formation
gene_pair_keep = ['MDK|LRP1',
 'FGFR1|FGFR2',
 'TIMP1|FGFR2',
 'CD44|FGFR2',                
 'CXCL12|ACKR3',               
 'GRN|EGFR',   
 'COPA|EGFR',                  
 'FAM3C|CXADR',             
 'FAM3C|LAMP1',
 'TGFB1|EGFR',  
 'MIF|EGFR',
 'MDK|SORL1',
 'EFNB1|EPHB6',
 'RSPO3|LGR5',
 'RSPO3|LGR6',
 'RSPO3|LGR4',
 'BMP7|PTPRK',
 'VEGFA|NRP2']

#missing in organoid compared to FS: 
#'IGF2|IGF1R',
#'EPHB6|EFNB2',
#'FAM3C|PDCD1',

# %%
array_fib8_filtered = array_fib8[array_fib8['gene_pair'].isin(gene_pair_keep)]
array_fib8_filtered
# Out:
#         gene_pair                                 cell_pair  new_mean  \
# 1      BMP7|PTPRK           Dermal papillia_Epithelial_late  0.590800
# 2      CD44|FGFR2         Dermal condensate_Epithelial_late  0.634000
# 3      CD44|FGFR2           Dermal papillia_Epithelial_late  0.634400
# 4      CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.468000
# 5      CD44|FGFR2    Pre-dermal condensate_Epithelial_early  0.767000
# 7       COPA|EGFR         Dermal condensate_Epithelial_late  0.547143
# 8       COPA|EGFR           Dermal papillia_Epithelial_late  0.510429
# 9       COPA|EGFR  Early fibroblasts HOXC5_Epithelial_early  0.480000
# 10      COPA|EGFR    Pre-dermal condensate_Epithelial_early  0.487000
# 13   CXCL12|ACKR3         Dermal condensate_Epithelial_late  0.339500
# 14   CXCL12|ACKR3  Early fibroblasts HOXC5_Epithelial_early  0.657000
# 15   CXCL12|ACKR3    Pre-dermal condensate_Epithelial_early  0.398000
# 25    EFNB1|EPHB6         Dermal condensate_Epithelial_late  0.332750
# 26    EFNB1|EPHB6           Dermal papillia_Epithelial_late  0.320000
# 32    FAM3C|CXADR         Dermal condensate_Epithelial_late  0.839857
# 33    FAM3C|CXADR           Dermal papillia_Epithelial_late  0.913571
# 34    FAM3C|CXADR    Pre-dermal condensate_Epithelial_early  0.561000
# 37    FAM3C|LAMP1         Dermal condensate_Epithelial_late  0.704571
# 38    FAM3C|LAMP1           Dermal papillia_Epithelial_late  0.778429
# 39    FAM3C|LAMP1    Pre-dermal condensate_Epithelial_early  0.615000
# 48    FGFR1|FGFR2         Dermal condensate_Epithelial_late  0.774000
# 49    FGFR1|FGFR2           Dermal papillia_Epithelial_late  0.907143
# 50    FGFR1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0
# 110       0.0  Early fibroblasts HOXC5
# 111       0.0    Pre-dermal condensate
# 117       0.0        Dermal condensate
# 118       0.0          Dermal papillia

# %%
# Add missing interactions to create equivalent plot with mean value 0

missing_df = pd.DataFrame({'gene_pair': ['IGF2|IGF1R','EPHB6|EFNB2','FAM3C|PDCD1'],
                   'cell_pair': ['Early fibroblasts HOXC5_Epithelial early', 'Early fibroblasts HOXC5_Epithelial early', 'Dermal condensate_Epithelial late'],
                   'new_mean': [0, 0, 0],
                   'min_padj': [0, 0, 0],
                   'Fibroblast': ['Early fibroblasts HOXC5','Early fibroblasts HOXC5','Dermal condensate']})
missing_df
# Out:
#      gene_pair                                 cell_pair  new_mean  min_padj  \
# 0   IGF2|IGF1R  Early fibroblasts HOXC5_Epithelial early         0         0
# 1  EPHB6|EFNB2  Early fibroblasts HOXC5_Epithelial early         0         0
# 2  FAM3C|PDCD1         Dermal condensate_Epithelial late         0         0
#
#                 Fibroblast
# 0  Early fibroblasts HOXC5
# 1  Early fibroblasts HOXC5
# 2        Dermal condensate

# %%
array_fib8_filtered = array_fib8_filtered.append(missing_df, ignore_index=True)
array_fib8_filtered
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 0     BMP7|PTPRK           Dermal papillia_Epithelial_late  0.590800
# 1     CD44|FGFR2         Dermal condensate_Epithelial_late  0.634000
# 2     CD44|FGFR2           Dermal papillia_Epithelial_late  0.634400
# 3     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.468000
# 4     CD44|FGFR2    Pre-dermal condensate_Epithelial_early  0.767000
# 5      COPA|EGFR         Dermal condensate_Epithelial_late  0.547143
# 6      COPA|EGFR           Dermal papillia_Epithelial_late  0.510429
# 7      COPA|EGFR  Early fibroblasts HOXC5_Epithelial_early  0.480000
# 8      COPA|EGFR    Pre-dermal condensate_Epithelial_early  0.487000
# 9   CXCL12|ACKR3         Dermal condensate_Epithelial_late  0.339500
# 10  CXCL12|ACKR3  Early fibroblasts HOXC5_Epithelial_early  0.657000
# 11  CXCL12|ACKR3    Pre-dermal condensate_Epithelial_early  0.398000
# 12   EFNB1|EPHB6         Dermal condensate_Epithelial_late  0.332750
# 13   EFNB1|EPHB6           Dermal papillia_Epithelial_late  0.320000
# 14   FAM3C|CXADR         Dermal condensate_Epithelial_late  0.839857
# 15   FAM3C|CXADR           Dermal papillia_Epithelial_late  0.913571
# 16   FAM3C|CXADR    Pre-dermal condensate_Epithelial_early  0.561000
# 17   FAM3C|LAMP1         Dermal condensate_Epithelial_late  0.704571
# 18   FAM3C|LAMP1           Dermal papillia_Epithelial_late  0.778429
# 19   FAM3C|LAMP1    Pre-dermal condensate_Epithelial_early  0.615000
# 20   FGFR1|FGFR2         Dermal condensate_Epithelial_late  0.774000
# 21   FGFR1|FGFR2           Dermal papillia_Epithelial_late  0.907143
# 22   FGFR1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0
# 36       0.0          Dermal papillia
# 37       0.0          Dermal papillia
# 38       0.0        Dermal condensate
# 39       0.0          Dermal papillia
# 40       0.0  Early fibroblasts HOXC5
# 41       0.0    Pre-dermal condensate
# 42       0.0        Dermal condensate
# 43       0.0          Dermal papillia
# 44       0.0  Early fibroblasts HOXC5
# 45       0.0    Pre-dermal condensate
# 46       0.0        Dermal condensate
# 47       0.0          Dermal papillia
# 48       0.0  Early fibroblasts HOXC5
# 49       0.0  Early fibroblasts HOXC5
# 50       0.0        Dermal condensate

# %%
#skip
#sorter = ['Early fibroblasts HOXC5_Epithelial_early', 'Pre-dermal condensate_Epithelial_early', 'Dermal condensate_Epithelial_late','Dermal papillia_Epithelial_late']
#sorterIndex = dict(zip(sorter, range(len(sorter))))
#array_fib8_filtered['cell_pair_Rank'] = array_fib8_filtered['cell_pair'].map(sorterIndex)
#array_fib8_filtered.sort_values(['cell_pair_Rank'],ascending = [True], inplace = True)
#array_fib8_filtered.drop('cell_pair_Rank', 1, inplace = True)
#array_fib8_filtered
# Out:
#        gene_pair                                 cell_pair  new_mean  \
# 3     CD44|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.468000
# 27      MDK|LRP1  Early fibroblasts HOXC5_Epithelial_early  1.224000
# 44   TIMP1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.716000
# 7      COPA|EGFR  Early fibroblasts HOXC5_Epithelial_early  0.480000
# 22   FGFR1|FGFR2  Early fibroblasts HOXC5_Epithelial_early  0.888000
# 40    TGFB1|EGFR  Early fibroblasts HOXC5_Epithelial_early  0.260000
# 10  CXCL12|ACKR3  Early fibroblasts HOXC5_Epithelial_early  0.657000
# 34    RSPO3|LGR4  Early fibroblasts HOXC5_Epithelial_early  0.436000
# 23   FGFR1|FGFR2    Pre-dermal condensate_Epithelial_early  0.868000
# 32      MIF|EGFR    Pre-dermal condensate_Epithelial_early  0.851000
# 28      MDK|LRP1    Pre-dermal condensate_Epithelial_early  0.955000
# 26      GRN|EGFR    Pre-dermal condensate_Epithelial_early  0.396000
# 19   FAM3C|LAMP1    Pre-dermal condensate_Epithelial_early  0.615000
# 41    TGFB1|EGFR    Pre-dermal condensate_Epithelial_early  0.277000
# 16   FAM3C|CXADR    Pre-dermal condensate_Epithelial_early  0.561000
# 35    RSPO3|LGR4    Pre-dermal condensate_Epithelial_early  0.387000
# 11  CXCL12|ACKR3    Pre-dermal condensate_Epithelial_early  0.398000
# 8      COPA|EGFR    Pre-dermal condensate_Epithelial_early  0.487000
# 45   TIMP1|FGFR2    Pre-dermal condensate_Epithelial_early  0.952000
# 4     CD44|FGFR2    Pre-dermal condensate_Epithelial_early  0.767000
# 14   FAM3C|CXADR         Dermal condensate_Epithelial_late  0.839857
# 1     CD44|FGFR2         Dermal condensate_Epithelial_late  0.634000
# 38    TGFB1|EGFR         Dermal condensate_Epithelial_late  0.404000
# 30      MIF|EGFR         Dermal condensate_Epithelial_late  0.852429
# 29     MDK|SORL1         Dermal condensate_Epithelial_late  0.799500
# 5      COPA|EGFR         Dermal condensate_Epithelial_late  0.547143
# 17   FAM3C|LAMP1         Dermal condensate_Epithelial_late  0.704571
# 42       0.0        Dermal condensate
# 43       0.0          Dermal papillia
# 37       0.0          Dermal papillia
# 39       0.0          Dermal papillia
# 0        0.0          Dermal papillia
# 33       0.0          Dermal papillia
# 31       0.0          Dermal papillia
# 25       0.0          Dermal papillia
# 21       0.0          Dermal papillia
# 18       0.0          Dermal papillia
# 15       0.0          Dermal papillia
# 13       0.0          Dermal papillia
# 6        0.0          Dermal papillia
# 2        0.0          Dermal papillia
# 36       0.0          Dermal papillia
# 47       0.0          Dermal papillia
# 48       0.0  Early fibroblasts HOXC5
# 49       0.0  Early fibroblasts HOXC5
# 50       0.0        Dermal condensate

# %%
array_fib8_plot_filtered = array_fib8_filtered.pivot_table(index='gene_pair', columns='cell_pair', values='new_mean', sort=False)
#array_fib8_plot_filtered

# %%
index_order = ['MDK|LRP1',
 'FGFR1|FGFR2',
 'TIMP1|FGFR2',
 'CD44|FGFR2',                
 'CXCL12|ACKR3',
 'IGF2|IGF1R',
 'GRN|EGFR',   
 'COPA|EGFR',                  
 'FAM3C|CXADR',
 'EPHB6|EFNB2',
 'FAM3C|LAMP1',
 'TGFB1|EGFR',  
 'MIF|EGFR',
 'MDK|SORL1',
 'EFNB1|EPHB6',
 'FAM3C|PDCD1',
 'RSPO3|LGR5',
 'RSPO3|LGR6',
 'RSPO3|LGR4',
 'BMP7|PTPRK',
 'VEGFA|NRP2']

array_fib8_plot_filtered = array_fib8_plot_filtered.loc[index_order]
#gene_sorterIndex = dict(zip(gene_sorter, range(len(gene_sorter))))
#array_fib8_plot_filtered['cell_pair_Rank'] = array_fib8_plot_filtered['gene_pair'].map(gene_sorterIndex)
#array_fib8_plot_filtered.sort_values(['cell_pair_Rank'],ascending = [True], inplace = True)
#array_fib8_plot_filtered.drop('cell_pair_Rank', 1, inplace = True)

# %%
column_order = ['Early fibroblasts HOXC5_Epithelial_early', 'Pre-dermal condensate_Epithelial_early', 'Dermal condensate_Epithelial_late','Dermal papillia_Epithelial_late']
array_fib8_plot_filtered = array_fib8_plot_filtered.replace(np.nan, 0) # copy df but with nans as 0
array_fib8_plot_filtered = array_fib8_plot_filtered[column_order] # reorder columns to correct order (x axis)
array_fib8_plot_filtered
# Out:
# cell_pair     Early fibroblasts HOXC5_Epithelial_early  \
# gene_pair
# MDK|LRP1                                         1.224
# FGFR1|FGFR2                                      0.888
# TIMP1|FGFR2                                      0.716
# CD44|FGFR2                                       0.468
# CXCL12|ACKR3                                     0.657
# IGF2|IGF1R                                       0.000
# GRN|EGFR                                         0.000
# COPA|EGFR                                        0.480
# FAM3C|CXADR                                      0.000
# EPHB6|EFNB2                                      0.000
# FAM3C|LAMP1                                      0.000
# TGFB1|EGFR                                       0.260
# MIF|EGFR                                         0.000
# MDK|SORL1                                        0.000
# EFNB1|EPHB6                                      0.000
# FAM3C|PDCD1                                      0.000
# RSPO3|LGR5                                       0.000
# RSPO3|LGR6                                       0.000
# RSPO3|LGR4                                       0.436
# BMP7|PTPRK                                       0.000
# VEGFA|NRP2                                       0.000
#
# cell_pair     Pre-dermal condensate_Epithelial_early  \
# gene_pair
# MDK|LRP1                                       0.955
# FGFR1|FGFR2                                    0.868
# TIMP1|FGFR2                                    0.952
# CD44|FGFR2                                     0.767
# CXCL12|ACKR3                                   0.398
# IGF2|IGF1R                                     0.000
# GRN|EGFR                                       0.396
# COPA|EGFR                                      0.487
# FAM3C|CXADR                                    0.561
# EPHB6|EFNB2                                    0.000
# FAM3C|LAMP1                                    0.615
# TGFB1|EGFR                                     0.277
# MIF|EGFR                                       0.851
# MDK|SORL1                                      0.000
# EFNB1|EPHB6                                    0.000
# FAM3C|PDCD1                                    0.000
# RSPO3|LGR5                                     0.000
# RSPO3|LGR6                                     0.000
# RSPO3|LGR4                                     0.387
# BMP7|PTPRK                                     0.000
# VEGFA|NRP2                                     0.000
#
# cell_pair     Dermal condensate_Epithelial_late  \
# gene_pair
# MDK|LRP1                               0.000000
# FGFR1|FGFR2                            0.774000
# TIMP1|FGFR2                            0.799571
# CD44|FGFR2                             0.634000
# CXCL12|ACKR3                           0.339500
# IGF2|IGF1R                             0.000000
# GRN|EGFR                               0.496571
# COPA|EGFR                              0.547143
# FAM3C|CXADR                            0.839857
# EPHB6|EFNB2                            0.000000
# FAM3C|LAMP1                            0.704571
# TGFB1|EGFR                             0.404000
# MIF|EGFR                               0.852429
# MDK|SORL1                              0.799500
# EFNB1|EPHB6                            0.332750
# FAM3C|PDCD1                            0.000000
# RSPO3|LGR5                             0.000000
# RSPO3|LGR6                             0.000000
# RSPO3|LGR4                             0.000000
# BMP7|PTPRK                             0.000000
# VEGFA|NRP2                             0.745500
#
# cell_pair     Dermal papillia_Epithelial_late
# gene_pair
# MDK|LRP1                             0.000000
# FGFR1|FGFR2                          0.907143
# TIMP1|FGFR2                          0.716400
# CD44|FGFR2                           0.634400
# CXCL12|ACKR3                         0.000000
# IGF2|IGF1R                           0.000000
# GRN|EGFR                             0.500429
# COPA|EGFR                            0.510429
# FAM3C|CXADR                          0.913571
# EPHB6|EFNB2                          0.000000
# FAM3C|LAMP1                          0.778429
# TGFB1|EGFR                           0.374857
# MIF|EGFR                             0.841429
# MDK|SORL1                            0.000000
# EFNB1|EPHB6                          0.320000
# FAM3C|PDCD1                          0.000000
# RSPO3|LGR5                           1.138000
# RSPO3|LGR6                           1.138667
# RSPO3|LGR4                           1.216143
# BMP7|PTPRK                           0.590800
# VEGFA|NRP2                           0.689500

# %%
# Plot - organoid
plt.subplots(figsize=(3,6))
ax = sn.heatmap(array_fib8_plot_filtered, cmap='rocket_r', linewidths=0.5, linecolor='white', square = True, annot=False, xticklabels=1, yticklabels=1, cbar_kws={"shrink": 0.5, 'label':'mean'})
for i in [plt.xticks, plt.yticks]:
    i(fontsize=8) 
for i in [ax.xaxis.label.set_size, ax.yaxis.label.set_size]:
    i(8)
#plt.savefig('/home/jovyan/projects/skin/fetal_skin/figures/marker_panels/CPDB_org_27062023.pdf',dpi=300, bbox_inches = "tight")
