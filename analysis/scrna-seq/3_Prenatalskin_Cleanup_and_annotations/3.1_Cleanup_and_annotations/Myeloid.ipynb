# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import anndata
import scanpy as sc
import scanpy_scripts as ss

np.set_printoptions(linewidth=180)
sc.settings.verbosity = 1
expr_cmap = ss.lib.expression_colormap()

# %%
ad = sc.read('../data/h5ad/20200114/fetal_skin.myeloid.doublet_removed_processed.20200114.h5ad')
# Out:
# WARNING: Your filename has more than two extensions: ['.myeloid', '.doublet_removed_processed', '.20200114', '.h5ad'].
# Only considering the two last: ['.20200114', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.myeloid', '.doublet_removed_processed', '.20200114', '.h5ad'].
# Only considering the two last: ['.20200114', '.h5ad'].

# %%
ad1 = sc.read('../data/h5ad/20191205/fetal_skin.monocytes.processed.20191205.h5ad')
# Out:
# WARNING: Your filename has more than two extensions: ['.monocytes', '.processed', '.20191205', '.h5ad'].
# Only considering the two last: ['.20191205', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.monocytes', '.processed', '.20191205', '.h5ad'].
# Only considering the two last: ['.20191205', '.h5ad'].

# %%
ad1
# Out:
# AnnData object with n_obs × n_vars = 11563 × 19884
#     obs: 'bh_doublet_pval', 'cell_caller', 'cluster_scrublet_score', 'doublet_pval', 'mt_prop', 'n_counts', 'n_genes', 'sanger_id', 'scrublet_score', 'chemistry', 'donor', 'gender', 'pcw', 'sorting', 'sample', 'chemistry_sorting', 'annot', 'hierarchy1', 'rachel_annot1', 'percent_mito', 'percent_ribo', 'percent_hb', 'percent_top50', 'leiden_hm_r0_1', 'leiden_hm_r0_2', 'leiden_hm_r0_3', 'leiden_hm_r0_4', 'leiden_hm_r0_5', 'leiden_bk_r0_1', 'leiden_bk_r0_2', 'leiden_bk_r0_3', 'leiden_bk_r0_4', 'leiden_bk_r0_5'
#     var: 'gene_ids', 'cc', 'mito', 'ribo', 'hb', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'hvg_full'
#     uns: 'leiden', 'neighbors', 'neighbors_bk', 'neighbors_hm', 'pca'
#     obsm: 'X_pca', 'X_pca_hm', 'X_umap_hm', 'X_umap_bk'
#     varm: 'PCs'

# %%
ss.lib.plot_embedding(ad1, basis='umap_hm', groupby='leiden_hm_r0_5', figsize=(3,3), size=5)

# %%
ss.lib.leiden(ad1, use_graph='neighbors_hm', restrict_to=('leiden_hm_r0_5', ('5',)), resolution=0.1, key_added='hm_split1')
# Out:
# ['leiden_hm_split1']

# %%
ss.lib.plot_embedding(ad1, basis='umap_hm', groupby='leiden_hm_split1', figsize=(3,3), size=5)

# %%
ad1.obs['rachel_annot3'] = ss.lib.regroup(ad1, groupby='leiden_hm_split1', regroups={
    'Monocyte': '0',
    'Monocyte (activated/differentiating?)': '3',
    'Neut-myeloid progenitor': '4',
    'Neutrophils1': '5,0',
    'Neutrophils2': '5,1',
    'DC2': '1',
    'ASDC': '6',
    'Mac doublets': '2',
})

# %%
asdc_cells = ad1.obs_names[ad1.obs.rachel_annot3=='ASDC']

# %%
ad.obs['is_asdc'] = ad.obs_names.isin(asdc_cells)
ad.obs['is_asdc'] = ad.obs['is_asdc'].astype('category')

# %%
ad.obs = ad.obs.merge(ad1.obs[['rachel_annot3']], how='left', left_index=True, right_index=True)

# %%
ad.obs['rachel_annot3_y'] = ad.obs['rachel_annot3_y'].astype('str').astype('category')

# %%
ss.lib.leiden(ad, use_graph='neighbors_hm', restrict_to=('leiden_hm_r0_4', ('7',)), resolution=0.3, key_added='hm_split1')
# Out:
# ['leiden_hm_split1']

# %%
ss.lib.leiden(ad, use_graph='neighbors_hm', restrict_to=('leiden_hm_split1', ('2',)), resolution=0.2, key_added='hm_split2')
# Out:
# ['leiden_hm_split2']

# %%
ss.lib.leiden(ad, use_graph='neighbors_hm', restrict_to=('leiden_hm_split2', ('9',)), resolution=0.2, key_added='hm_split3')
# Out:
# ['leiden_hm_split3']

# %%
ss.lib.leiden(ad, use_graph='neighbors_hm', restrict_to=('leiden_hm_split3', ('1',)), resolution=0.2, key_added='hm_split4')
# Out:
# ['leiden_hm_split4']

# %%
ss.lib.leiden(ad, use_graph='neighbors_hm', restrict_to=('leiden_hm_split4', ('1,1',)), resolution=0.5, key_added='hm_split5')
# Out:
# ['leiden_hm_split5']

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_r0_4', palette='tab20')

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_split1', palette='tab20')

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_split2', palette='tab20')

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_split3', palette='tab20')

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_split4', palette='tab20')

# %%
ss.lib.plot_embedding(ad, basis='umap_hm', groupby='leiden_hm_split5', palette='tab20')

# %%
ss.lib.cross_table(ad, 'rachel_annot3_y', 'leiden_hm_split5', highlight=1)
# Out:
# <style  type="text/css" >
#     #T_29286ede_7758_11ea_a942_fa163e95567frow0_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col8 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col9 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col10 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col11 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col12 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col14 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col15 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col16 {
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col17 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col18 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col19 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow0_col20 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col2 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col7 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col8 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col9 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col11 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col12 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col14 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col15 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col16 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col17 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col18 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col19 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow1_col20 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col0 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col1 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col2 {
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col4 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col5 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col6 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col7 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col8 {
#             background-color:  #27808e;
#             color:  #000000;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col9 {
#             background-color:  #fbe723;
#             color:  #000000;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col11 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col12 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col13 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col14 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col15 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col16 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_29286ede_7758_11ea_a942_fa163e95567frow2_col17 {
#             background-color:  #440154;

# %%
ad.obs['rachel_annot3'] = ss.lib.regroup(ad, groupby='leiden_hm_split5', regroups={
    'Macrophage1': '0',
    'Macrophage2': '3',
    'Activated mac?': '7,1',
    'Monocyte': '1,0',
    'Monocyte (activated/differentiating?)': ['1,1,0', '1,1,2', '1,1,3'],
    'Neut-myeloid progenitor': ['1,2', '9,0'],
    'Neutrophil1': '9,2',
    'Neutrophil2': '9,1',
    'Microglia': '5',
    'DC1': '8',
    'DC2': ['2,0'],
    'ASDC?': '2,2',
    'Inflammatory DC?': '7,2',
    'LC': '11',
    'Mac-mono': ['1,1,1', '1,1,4', '2,1'],
    'Skeletal muscle? doublet': '7,0',
})

# %%
ad.obs.rachel_annot3.value_counts()
# Out:
# Macrophage1                              18058
# Monocyte                                  3181
# DC2                                       2538
# Macrophage2                               2224
# Mac-mono                                  2202
# Monocyte (activated/differentiating?)     2034
# Neut-myeloid progenitor                   1734
# Microglia                                 1617
# DC1                                        756
# Skeletal muscle? doublet                   418
# LC                                         380
# Activated mac?                             330
# Neutrophil2                                174
# ASDC?                                       90
# Neutrophil1                                 88
# Inflammatory DC?                            80
# Name: rachel_annot3, dtype: int64

# %%
ad2 = ad[~ad.obs.rachel_annot3.str.endswith('doublet'), :].copy()

# %%
ss.lib.clear_colors(ad2)
ss.lib.plot_embedding(ad2, basis='umap_hm', groupby='rachel_annot3', palette='tab20')

# %%
ss.lib.clear_colors(ad2)

# %%
ad.write('fetal_skin.myeloid.doublet_removed_processed.20200403.h5ad', compression='lzf')

# %%
ad = sc.read('fetal_skin.myeloid.doublet_removed_processed.20200403.h5ad')
# Out:
# WARNING: Your filename has more than two extensions: ['.myeloid', '.doublet_removed_processed', '.20200403', '.h5ad'].
# Only considering the two last: ['.20200403', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.myeloid', '.doublet_removed_processed', '.20200403', '.h5ad'].
# Only considering the two last: ['.20200403', '.h5ad'].

# %%
genes = ['CD83', 'RELB', 'CD86', 'CD40', 'SOCS1', 'ALDH1A2', 'FAS', 'CD200', 'PDCD1LG2', 'CD274']

# %%
sc.pl.dotplot(ad, genes, groupby='rachel_annot3', mean_only_expressed=True)
# Out:
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[3.5, 0, 0.2, 0.5, 0.25])
